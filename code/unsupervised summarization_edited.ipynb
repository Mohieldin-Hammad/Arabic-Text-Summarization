# %%
article_text = "وبعد أن ألقينا الضوء على أهم فتوحات بلاد الشام تعال معا نتناول بيت المقدس بوصفه نموذجا لفتوحات هذه البلاد بشيء من التفصيل .\nفتح بيت المقدس ١٥هـ \/ ٦٣٦م:\nلحق عمرو بن العاص بالروم، وشدد عليهم الحصار ، ولم يتمكن الروم من فكه، وهرب الأرطبون إلى مصر مركز ثقل الوجود البيزنطي في إفريقيا لصد هجمات المسلمين.\nوأثناء الحصار كانت تجرى محادثات لدخول أهل بيت المقدس في الصلح مع المسلمين، فلم يجد بطريرك بيت المقدس أمامه سوى المصالحة، ولكنه اشترط أن يتم الصلح مع الخليفة عمر بن الخطاب بنفسه وذلك لما للمدينة من قدسية وأهمية دينية كبيرة، فأرسل عمرو بن العاص بهذه الأخبار إلى الخليفة بالمدينة النبوية، وقال له في رسالته: \"إني أعالج حربا كؤدًا صدومًا وبلادا ادخرت لك فلك رأيك\" فكان أول خروج للخليفة من المدينة بعد موت رسول الله ، هذا الخروج الأجل لكي يفتح بيت المقدس . وكان أول نزول له بمدن الشام بالجابية، والتي وفدت عليه فيها رسل البطريرك طالبين الصلح، فصالحهم عمر صلحا لم تحظ به مدينة أخرى في البلاد المفتوحة.... \nهل تعرف شروط هذا الصلح ؟\nاقرأ النص التالى لتتعرف كيف كان الخليفة عمر سخيا في منحه الامتيازات لأهل إيلياء (بيت المقدس).\nعهد الأمان\n\"بسم الله الرحمن الرحيم: هذا ما أعطى عبد الله عمر أمير المؤمنين أهل إيلياء من الأمان، أعطاهم أمانا لأنفسهم وأموالهم وكنائسهم، وصلبانهم، وسقيمها وبريئها، وسائر ملتها، أنه لا تسكن كنائسهم، ولا تهدم، ولا ينتقص منها ولا من حيزها ولا من صليبهم، وشيء من أموالهم، ولا يكرهون على دينهم، ولا يضار أحد منهم، ولا يسكن بإيلياء أحد من اليهود، وعلى أهل إيلياء الجزية كما يعطي أهل المدائن وعليهم أن يخرجوا منها الروم، واللصوص، فمن خرج منهم، فإنه أمن على نفسه وماله حتى يبلغوا مأمنهم، ومن أقام منهم فهو آمن وعليه مثل ما على أهل إيلياء من الجزية ومن أحب من أهل إيلياء أن يسير بنفسه وماله مع الروم ويخلي بيعهم وصلبهم فإنهم آمنون على أنفسهم وعلى بيعهم وصلبهم حتى يبلغوا مأمنهم، ومن شاء رجع إلى أهله فإنه لا يؤخذ منهم شيء حتى يحصد حصادهم، وعلى ما في هذا الكتاب عهد الله وذمة رسوله وذمة الخلفاء وذمة المؤمنين إذا أعطوا الذي عليهم من الجزية.\n"
# article_text = "سادسا: الحياة الفنية:\nا. العمارة:\nبلغ الرومـان فـي العمارة درجـة كبيرة من الاتقان، حتى أصبـح فـن الـعمـارة الرومانـي هـو أهـم مظهر فنى للدولة الرومانيـة وجـاء مزيجـا مـن العمارة اليونانية والمصرية، والبقايـا الأثرية حتى الآن تبـرز مـدى التفاعل الحضـاري بيـن الحضـارات، وقـد أنشـأ الرومـان أكثـر المـدن روعـة فـي التاريـخ وهـي مدينـة رومـا، ومـا تميـزت بـه مـن منشـآت ضخمـة كالمعابـد والقصـور والحمامات\nوأقـواس النصـر.\n.. النحت:\nمـن أهـم مـا يميـز فـن النـحـت الرومانـي واقعيتـه الشـديدة خاصـة فـي نـحـت التماثيل الشخصية، مثـل رأس قيصـر المصنـوع مـن حـجـر البازلت وتمثال\"بومبي\". كان من أهم ماتفوق فيه الرومان النقوش البارزة على الجدران والأعمدة، واستخدموا هذه النقوش كزخارف وزينة ومن أمثلتها: نقوش عمود تراجان.\nزخـارف الصلصـال المحـروق علـى جـدران المعابـد، وقـد تجلـي فـي نحتـهـم دقـة العمـل والتعبيـر عـن الشـعور. ومـن روائـع فـن النـحـت الرومانـي أيضـا النقـوش\\ الموجـودة علـى أقـواس النصـر التـي كـانـت تقـام تخليدا لانتصـارات القادة العظـام والأباطـرة، وأجملهـا قـوس الإمبراطـور تيتـوس.\n3. التصوير الروماني:\nانتقل فن التصوير الإغريقي إلى رومـا بـانتقـال الرسامين الإغريق إلى روما عاصمة الإمبراطورية.\nوقد ازدهـر فـن التصوير القديـم أي الرسـم وازداد انتشـارا عنـد الرومـان لحاجـة المسكن الروماني إلى تجميل حوائطـه مـن الداخـل واستخدم النبلاء الرومـان المصورين الإغريـق فـي تزييـن جـدران قصورهـم بالرسوم الملونـة لتنقل الطبيعة والحيـاة مـن خـارج المسكن إلى داخلـه؛ كمـا اهتمـوا بزخرفة أرضيات الحجـرات بلوحـات مـن الفسيفساء الملـون التـي تحمـل مناظـر مـعبـرة.\nالتواصل الفنى:\nأقام الرومان بالإسكندرية العديد من المنشآت المعمارية، والتي تأثرت بالحضـارة الإغريقية والمصريـة مثـل: البوابـات والمسارح والمعابـد، كمـا تأثـر النحت الرومانـي بالنحـت المصـرى... لاحـظ الصـورة التـي أمـامـك\nلتتعرف عليهـا… وهكذا كانت الحضارة المصرية القديمـة رمـزا للتواصل الحضـاري مع حضـارات الـعـالـم القديـم، وأحـد مـعـالـم التبادل الثقافي والفنـي والدينـي مـع شـعـوبـه مـن خـلال عمليـات الأخـذ والعطـاء والتأثير والتأثـر... فهـل يمكـن\nلمصـر إعادة هـذا الـدور الحضـاري الريـادي مـن جديد؟\n"
# article_text = "الاهرامات الجيزه الهضبه الجنوبيه للمجمع اليمين للشمال الهرم الاكبر هرم خوفو هرم خفرع اصغر الاهرامات الثلاثة هرم منقرع مصطبة فرعون فى سقاره الاهرامات المصريه اكبر الابنيه القديمه وتشكل واحده اقوى رموز الحضاره المصريه القديمه واتبنيت معظم الاهرامات المصريه خلال فترات المملكة القديمة المملكة الوسطانية ايد قدماء المصريين فى الضفه الغربيه لنهر النيل علشان كانت بتعتبر ارض الميتين ايمانهم السودان توجد اهرامات أقدم الاهرامات المصرية لكنها اصغر التطور التاريخى فى الفتره المبكره التاريخ المصرى الوسائل الكافيه الدفن بيتم فى مبنى يشبه الهياكل المعروفه بالمصاطب زى مصطبة فرعون فى سقاره اول هرم مصرى موثق تاريخيا يرجع للمهندس المعمارى امحوتب عدد وموقع الاهرامات عدد الهياكل الهرميه فى مصر النهارده هرم ليستة أهرامات مصر مراجع الاهرامات المصريه تصنيف تاريخ مصر العمرانى"
article_text
# Out:
# 'وبعد أن ألقينا الضوء على أهم فتوحات بلاد الشام تعال معا نتناول بيت المقدس بوصفه نموذجا لفتوحات هذه البلاد بشيء من التفصيل .\nفتح بيت المقدس ١٥هـ \\/ ٦٣٦م:\nلحق عمرو بن العاص بالروم، وشدد عليهم الحصار ، ولم يتمكن الروم من فكه، وهرب الأرطبون إلى مصر مركز ثقل الوجود البيزنطي في إفريقيا لصد هجمات المسلمين.\nوأثناء الحصار كانت تجرى محادثات لدخول أهل بيت المقدس في الصلح مع المسلمين، فلم يجد بطريرك بيت المقدس أمامه سوى المصالحة، ولكنه اشترط أن يتم الصلح مع الخليفة عمر بن الخطاب بنفسه وذلك لما للمدينة من قدسية وأهمية دينية كبيرة، فأرسل عمرو بن العاص بهذه الأخبار إلى الخليفة بالمدينة النبوية، وقال له في رسالته: "إني أعالج حربا كؤدًا صدومًا وبلادا ادخرت لك فلك رأيك" فكان أول خروج للخليفة من المدينة بعد موت رسول الله ، هذا الخروج الأجل لكي يفتح بيت المقدس . وكان أول نزول له بمدن الشام بالجابية، والتي وفدت عليه فيها رسل البطريرك طالبين الصلح، فصالحهم عمر صلحا لم تحظ به مدينة أخرى في البلاد المفتوحة.... \nهل تعرف شروط هذا الصلح ؟\nاقرأ النص التالى لتتعرف كيف كان الخليفة عمر سخيا في منحه الامتيازات لأهل إيلياء (بيت المقدس).\nعهد الأمان\n"بسم الله الرحمن الرحيم: هذا ما أعطى عبد الله عمر أمير المؤمنين أهل إيلياء من الأمان، أعطاهم أمانا لأنفسهم وأموالهم وكنائسهم، وصلبانهم، وسقيمها وبريئها، وسائر ملتها، أنه لا تسكن كنائسهم، ولا تهدم، ولا ينتقص منها ولا من حيزها ولا من صليبهم، وشيء من أموالهم، ولا يكرهون على دينهم، ولا يضار أحد منهم، ولا يسكن بإيلياء أحد من اليهود، وعلى أهل إيلياء الجزية كما يعطي أهل المدائن وعليهم أن يخرجوا منها الروم، واللصوص، فمن خرج منهم، فإنه أمن على نفسه وماله حتى يبلغوا مأمنهم، ومن أقام منهم فهو آمن وعليه مثل ما على أهل إيلياء من الجزية ومن أحب من أهل إيلياء أن يسير بنفسه وماله مع الروم ويخلي بيعهم وصلبهم فإنهم آمنون على أنفسهم وعلى بيعهم وصلبهم حتى يبلغوا مأمنهم، ومن شاء رجع إلى أهله فإنه لا يؤخذ منهم شيء حتى يحصد حصادهم، وعلى ما في هذا الكتاب عهد الله وذمة رسوله وذمة الخلفاء وذمة المؤمنين إذا أعطوا الذي عليهم من الجزية.\n'

# %%
import re

article_text = re.sub(r'\n', ' ', article_text)
article_text = re.sub(r'\s+', ' ', article_text)
article_text = re.sub(r',', '', article_text)

formatted_article_text = re.sub('[^\u0621-\u064A\u0660-\u0669 ]', ' ', article_text)
formatted_article_text = re.sub(r'\s+', ' ', formatted_article_text)
formatted_article_text
# Out:
# 'وبعد أن ألقينا الضوء على أهم فتوحات بلاد الشام تعال معا نتناول بيت المقدس بوصفه نموذجا لفتوحات هذه البلاد بشيء من التفصيل فتح بيت المقدس ١٥هـ ٦٣٦م لحق عمرو بن العاص بالروم وشدد عليهم الحصار ولم يتمكن الروم من فكه وهرب الأرطبون إلى مصر مركز ثقل الوجود البيزنطي في إفريقيا لصد هجمات المسلمين وأثناء الحصار كانت تجرى محادثات لدخول أهل بيت المقدس في الصلح مع المسلمين فلم يجد بطريرك بيت المقدس أمامه سوى المصالحة ولكنه اشترط أن يتم الصلح مع الخليفة عمر بن الخطاب بنفسه وذلك لما للمدينة من قدسية وأهمية دينية كبيرة فأرسل عمرو بن العاص بهذه الأخبار إلى الخليفة بالمدينة النبوية وقال له في رسالته إني أعالج حربا كؤد ا صدوم ا وبلادا ادخرت لك فلك رأيك فكان أول خروج للخليفة من المدينة بعد موت رسول الله هذا الخروج الأجل لكي يفتح بيت المقدس وكان أول نزول له بمدن الشام بالجابية والتي وفدت عليه فيها رسل البطريرك طالبين الصلح فصالحهم عمر صلحا لم تحظ به مدينة أخرى في البلاد المفتوحة هل تعرف شروط هذا الصلح اقرأ النص التالى لتتعرف كيف كان الخليفة عمر سخيا في منحه الامتيازات لأهل إيلياء بيت المقدس عهد الأمان بسم الله الرحمن الرحيم هذا ما أعطى عبد الله عمر أمير المؤمنين أهل إيلياء من الأمان أعطاهم أمانا لأنفسهم وأموالهم وكنائسهم وصلبانهم وسقيمها وبريئها وسائر ملتها أنه لا تسكن كنائسهم ولا تهدم ولا ينتقص منها ولا من حيزها ولا من صليبهم وشيء من أموالهم ولا يكرهون على دينهم ولا يضار أحد منهم ولا يسكن بإيلياء أحد من اليهود وعلى أهل إيلياء الجزية كما يعطي أهل المدائن وعليهم أن يخرجوا منها الروم واللصوص فمن خرج منهم فإنه أمن على نفسه وماله حتى يبلغوا مأمنهم ومن أقام منهم فهو آمن وعليه مثل ما على أهل إيلياء من الجزية ومن أحب من أهل إيلياء أن يسير بنفسه وماله مع الروم ويخلي بيعهم وصلبهم فإنهم آمنون على أنفسهم وعلى بيعهم وصلبهم حتى يبلغوا مأمنهم ومن شاء رجع إلى أهله فإنه لا يؤخذ منهم شيء حتى يحصد حصادهم وعلى ما في هذا الكتاب عهد الله وذمة رسوله وذمة الخلفاء وذمة المؤمنين إذا أعطوا الذي عليهم من الجزية '

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import heapq

# %%
import nltk

# Set the appropriate language code for Arabic stopwords
stopwords = nltk.corpus.stopwords.words('arabic')

word_frequencies = {}
for word in nltk.word_tokenize(formatted_article_text):
    if word not in stopwords:
        if word not in word_frequencies.keys():
            word_frequencies[word] = 1
        else:
            word_frequencies[word] += 1
word_frequencies
# Out:
# {'سادسا': 1,
#  'الحياة': 1,
#  'الفنية': 1,
#  'العمارة': 3,
#  'بلغ': 1,
#  'الرومـان': 4,
#  'فـي': 5,
#  'درجـة': 1,
#  'كبيرة': 1,
#  'الاتقان': 1,
#  'أصبـح': 1,
#  'فـن': 4,
#  'الـعمـارة': 1,
#  'الرومانـي': 4,
#  'هـو': 1,
#  'أهـم': 2,
#  'مظهر': 1,
#  'فنى': 1,
#  'للدولة': 1,
#  'الرومانيـة': 1,
#  'وجـاء': 1,
#  'مزيجـا': 1,
#  'مـن': 9,
#  'اليونانية': 1,
#  'والمصرية': 1,
#  'والبقايـا': 1,
#  'الأثرية': 1,
#  'تبـرز': 1,
#  'مـدى': 1,
#  'التفاعل': 1,
#  'الحضـاري': 3,
#  'بيـن': 1,
#  'الحضـارات': 1,
#  'وقـد': 2,
#  'أنشـأ': 1,
#  'أكثـر': 1,
#  'المـدن': 1,
#  'روعـة': 1,
#  'التاريـخ': 1,
#  'وهـي': 1,
#  'مدينـة': 1,
#  'رومـا': 2,
#  'ومـا': 1,
#  'تميـزت': 1,
#  'بـه': 1,
#  'منشـآت': 1,
#  'ضخمـة': 1,
#  'كالمعابـد': 1,
#  'والقصـور': 1,
#  'والحمامات': 1,
#  'وأقـواس': 1,
#  'النصـر': 2,
#  'النحت': 2,
#  'مـا': 1,
#  'يميـز': 1,
#  'النـحـت': 2,
#  'واقعيتـه': 1,
#  'الشـديدة': 1,
#  'خاصـة': 1,
#  'نـحـت': 1,
#  'التماثيل': 1,
#  'الشخصية': 1,
#  'مثـل': 2,
#  'رأس': 1,
#  'قيصـر': 1,
#  'المصنـوع': 1,
#  'حـجـر': 1,
#  'البازلت': 1,
#  'وتمثال': 1,
#  'بومبي': 1,
#  'أهم': 1,
#  'ماتفوق': 1,
#  'الرومان': 2,
#  'النقوش': 2,
#  'البارزة': 1,
#  'الجدران': 1,
#  'والأعمدة': 1,
#  'واستخدموا': 1,
#  'كزخارف': 1,
#  'وزينة': 1,
#  'أمثلتها': 1,
#  'نقوش': 1,
#  'عمود': 1,
#  'تراجان': 1,
#  'زخـارف': 1,
#  'الصلصـال': 1,
#  'المحـروق': 1,
#  'علـى': 2,
#  'جـدران': 2,
#  'المعابـد': 1,
#  'تجلـي': 1,
#  'نحتـهـم': 1,
#  'دقـة': 1,
#  'العمـل': 1,
#  'والتعبيـر': 1,
#  'عـن': 1,
#  'الشـعور': 1,
#  'ومـن': 1,
#  'روائـع': 1,
#  'أيضـا': 1,
#  'النقـوش': 1,
#  'الموجـودة': 1,
#  'أقـواس': 1,
#  'التـي': 3,
#  'كـانـت': 1,
#  'تقـام': 1,
#  'تخليدا': 1,
#  'لانتصـارات': 1,
#  'القادة': 1,
#  'العظـام': 1,
#  'والأباطـرة': 1,
#  'وأجملهـا': 1,
#  'قـوس': 1,
#  'الإمبراطـور': 1,
#  'تيتـوس': 1,
#  'التصوير': 3,
#  'الروماني': 2,
#  'انتقل': 1,
#  'فن': 1,
#  'الإغريقي': 1,
#  'بـانتقـال': 1,
#  'الرسامين': 1,
#  'الإغريق': 1,
#  'روما': 1,
#  'عاصمة': 1,
#  'الإمبراطورية': 1,
#  'وقد': 1,
#  'ازدهـر': 1,
#  'القديـم': 2,
#  'الرسـم': 1,
#  'وازداد': 1,
#  'انتشـارا': 1,
#  'عنـد': 1,
#  'لحاجـة': 1,
#  'المسكن': 2,
#  'تجميل': 1,
#  'حوائطـه': 1,
#  'الداخـل': 1,
#  'واستخدم': 1,
#  'النبلاء': 1,
#  'المصورين': 1,
#  'الإغريـق': 1,
#  'تزييـن': 1,
#  'قصورهـم': 1,
#  'بالرسوم': 1,
#  'الملونـة': 1,
#  'لتنقل': 1,
#  'الطبيعة': 1,
#  'والحيـاة': 1,
#  'خـارج': 1,
#  'داخلـه': 1,
#  'كمـا': 2,
#  'اهتمـوا': 1,
#  'بزخرفة': 1,
#  'أرضيات': 1,
#  'الحجـرات': 1,
#  'بلوحـات': 1,
#  'الفسيفساء': 1,
#  'الملـون': 1,
#  'تحمـل': 1,
#  'مناظـر': 1,
#  'مـعبـرة': 1,
#  'التواصل': 1,
#  'الفنى': 1,
#  'أقام': 1,
#  'بالإسكندرية': 1,
#  'العديد': 1,
#  'المنشآت': 1,
#  'المعمارية': 1,
#  'والتي': 1,
#  'تأثرت': 1,
#  'بالحضـارة': 1,
#  'الإغريقية': 1,
#  'والمصريـة': 1,
#  'البوابـات': 1,
#  'والمسارح': 1,
#  'والمعابـد': 1,
#  'تأثـر': 1,
#  'بالنحـت': 1,
#  'المصـرى': 1,
#  'لاحـظ': 1,
#  'الصـورة': 1,
#  'أمـامـك': 1,
#  'لتتعرف': 1,
#  'عليهـا': 1,
#  'وهكذا': 1,
#  'كانت': 1,
#  'الحضارة': 1,
#  'المصرية': 1,
#  'القديمـة': 1,
#  'رمـزا': 1,
#  'للتواصل': 1,
#  'حضـارات': 1,
#  'الـعـالـم': 1,
#  'وأحـد': 1,
#  'مـعـالـم': 1,
#  'التبادل': 1,
#  'الثقافي': 1,
#  'والفنـي': 1,
#  'والدينـي': 1,
#  'مـع': 1,
#  'شـعـوبـه': 1,
#  'خـلال': 1,
#  'عمليـات': 1,
#  'الأخـذ': 1,
#  'والعطـاء': 1,
#  'والتأثير': 1,
#  'والتأثـر': 1,
#  'فهـل': 1,
#  'يمكـن': 1,
#  'لمصـر': 1,
#  'إعادة': 1,
#  'هـذا': 1,
#  'الـدور': 1,
#  'الريـادي': 1,
#  'جديد': 1}

# %%
from pyarabic.araby import tokenize
sentence_list = tokenize(article_text)

# %%
# sentence_list = nltk.sent_tokenize(article_text)

# %%
sentence_list
# Out:
# ['سادسا',
#  ':',
#  'الحياة',
#  'الفنية',
#  ':',
#  'ا',
#  '.',
#  'العمارة',
#  ':',
#  'بلغ',
#  'الرومـان',
#  'فـي',
#  'العمارة',
#  'درجـة',
#  'كبيرة',
#  'من',
#  'الاتقان',
#  '،',
#  'حتى',
#  'أصبـح',
#  'فـن',
#  'الـعمـارة',
#  'الرومانـي',
#  'هـو',
#  'أهـم',
#  'مظهر',
#  'فنى',
#  'للدولة',
#  'الرومانيـة',
#  'وجـاء',
#  'مزيجـا',
#  'مـن',
#  'العمارة',
#  'اليونانية',
#  'والمصرية',
#  '،',
#  'والبقايـا',
#  'الأثرية',
#  'حتى',
#  'الآن',
#  'تبـرز',
#  'مـدى',
#  'التفاعل',
#  'الحضـاري',
#  'بيـن',
#  'الحضـارات',
#  '،',
#  'وقـد',
#  'أنشـأ',
#  'الرومـان',
#  'أكثـر',
#  'المـدن',
#  'روعـة',
#  'فـي',
#  'التاريـخ',
#  'وهـي',
#  'مدينـة',
#  'رومـا',
#  '،',
#  'ومـا',
#  'تميـزت',
#  'بـه',
#  'مـن',
#  'منشـآت',
#  'ضخمـة',
#  'كالمعابـد',
#  'والقصـور',
#  'والحمامات',
#  'وأقـواس',
#  'النصـر',
#  '...',
#  'النحت',
#  ':',
#  'مـن',
#  'أهـم',
#  'مـا',
#  'يميـز',
#  'فـن',
#  'النـحـت',
#  'الرومانـي',
#  'واقعيتـه',
#  'الشـديدة',
#  'خاصـة',
#  'فـي',
#  'نـحـت',
#  'التماثيل',
#  'الشخصية',
#  '،',
#  'مثـل',
#  'رأس',
#  'قيصـر',
#  'المصنـوع',
#  'مـن',
#  'حـجـر',
#  'البازلت',
#  'وتمثال',
#  '"',
#  'بومبي',
#  '".',
#  'كان',
#  'من',
#  'أهم',
#  'ماتفوق',
#  'فيه',
#  'الرومان',
#  'النقوش',
#  'البارزة',
#  'على',
#  'الجدران',
#  'والأعمدة',
#  '،',
#  'واستخدموا',
#  'هذه',
#  'النقوش',
#  'كزخارف',
#  'وزينة',
#  'ومن',
#  'أمثلتها',
#  ':',
#  'نقوش',
#  'عمود',
#  'تراجان',
#  '.',
#  'زخـارف',
#  'الصلصـال',
#  'المحـروق',
#  'علـى',
#  'جـدران',
#  'المعابـد',
#  '،',
#  'وقـد',
#  'تجلـي',
#  'فـي',
#  'نحتـهـم',
#  'دقـة',
#  'العمـل',
#  'والتعبيـر',
#  'عـن',
#  'الشـعور',
#  '.',
#  'ومـن',
#  'روائـع',
#  'فـن',
#  'النـحـت',
#  'الرومانـي',
#  'أيضـا',
#  'النقـوش',
#  '\\',
#  'الموجـودة',
#  'علـى',
#  'أقـواس',
#  'النصـر',
#  'التـي',
#  'كـانـت',
#  'تقـام',
#  'تخليدا',
#  'لانتصـارات',
#  'القادة',
#  'العظـام',
#  'والأباطـرة',
#  '،',
#  'وأجملهـا',
#  'قـوس',
#  'الإمبراطـور',
#  'تيتـوس',
#  '.',
#  '3',
#  '.',
#  'التصوير',
#  'الروماني',
#  ':',
#  'انتقل',
#  'فن',
#  'التصوير',
#  'الإغريقي',
#  'إلى',
#  'رومـا',
#  'بـانتقـال',
#  'الرسامين',
#  'الإغريق',
#  'إلى',
#  'روما',
#  'عاصمة',
#  'الإمبراطورية',
#  '.',
#  'وقد',
#  'ازدهـر',
#  'فـن',
#  'التصوير',
#  'القديـم',
#  'أي',
#  'الرسـم',
#  'وازداد',
#  'انتشـارا',
#  'عنـد',
#  'الرومـان',
#  'لحاجـة',
#  'المسكن',
#  'الروماني',
#  'إلى',
#  'تجميل',
#  'حوائطـه',
#  'مـن',
#  'الداخـل',
#  'واستخدم',
#  'النبلاء',
#  'الرومـان',
#  'المصورين',
#  'الإغريـق',
#  'فـي',
#  'تزييـن',
#  'جـدران',
#  'قصورهـم',
#  'بالرسوم',
#  'الملونـة',
#  'لتنقل',
#  'الطبيعة',
#  'والحيـاة',
#  'مـن',
#  'خـارج',
#  'المسكن',
#  'إلى',
#  'داخلـه',
#  '؛',
#  'كمـا',
#  'اهتمـوا',
#  'بزخرفة',
#  'أرضيات',
#  'الحجـرات',
#  'بلوحـات',
#  'مـن',
#  'الفسيفساء',
#  'الملـون',
#  'التـي',
#  'تحمـل',
#  'مناظـر',
#  'مـعبـرة',
#  '.',
#  'التواصل',
#  'الفنى',
#  ':',
#  'أقام',
#  'الرومان',
#  'بالإسكندرية',
#  'العديد',
#  'من',
#  'المنشآت',
#  'المعمارية',
#  '،',
#  'والتي',
#  'تأثرت',
#  'بالحضـارة',
#  'الإغريقية',
#  'والمصريـة',
#  'مثـل',
#  ':',
#  'البوابـات',
#  'والمسارح',
#  'والمعابـد',
#  '،',
#  'كمـا',
#  'تأثـر',
#  'النحت',
#  'الرومانـي',
#  'بالنحـت',
#  'المصـرى',
#  '...',
#  'لاحـظ',
#  'الصـورة',
#  'التـي',
#  'أمـامـك',
#  'لتتعرف',
#  'عليهـا',
#  '…',
#  'وهكذا',
#  'كانت',
#  'الحضارة',
#  'المصرية',
#  'القديمـة',
#  'رمـزا',
#  'للتواصل',
#  'الحضـاري',
#  'مع',
#  'حضـارات',
#  'الـعـالـم',
#  'القديـم',
#  '،',
#  'وأحـد',
#  'مـعـالـم',
#  'التبادل',
#  'الثقافي',
#  'والفنـي',
#  'والدينـي',
#  'مـع',
#  'شـعـوبـه',
#  'مـن',
#  'خـلال',
#  'عمليـات',
#  'الأخـذ',
#  'والعطـاء',
#  'والتأثير',
#  'والتأثـر',
#  '...',
#  'فهـل',
#  'يمكـن',
#  'لمصـر',
#  'إعادة',
#  'هـذا',
#  'الـدور',
#  'الحضـاري',
#  'الريـادي',
#  'مـن',
#  'جديد',
#  '؟']

# %%
# Step 4: Calculate word frequencies
word_frequencies = {}
for word in tokenize(formatted_article_text):
    if word not in stopwords:
        if word not in word_frequencies.keys():
            word_frequencies[word] = 1
        else:
            word_frequencies[word] += 1

# Step 5: Calculate sentence scores
maximum_frequency = max(word_frequencies.values())
for word in word_frequencies.keys():
    word_frequencies[word] = (word_frequencies[word] / maximum_frequency)

sentence_scores = {}
for sent in sentence_list:
    for word in tokenize(sent):
        if word in word_frequencies.keys():
            if len(sent.split(' ')) < 30:
                if sent not in sentence_scores.keys():
                    sentence_scores[sent] = word_frequencies[word]
                else:
                    sentence_scores[sent] += word_frequencies[word]

# Step 6: Get the top sentences based on scores
summary_sentences = heapq.nlargest(20, sentence_scores, key=sentence_scores.get)

summary = ' '.join(summary_sentences)
print(summary)
# Out:
# مـن فـي الرومـان فـن الرومانـي العمارة الحضـاري التـي التصوير أهـم وقـد رومـا النصـر النحت النـحـت مثـل الرومان النقوش علـى جـدران

# %%
maximum_frequency = max(word_frequencies.values())
for word in word_frequencies.keys():
    word_frequencies[word] = (word_frequencies[word] / maximum_frequency)
#     print(word_frequencies)

sentence_scores = {}
for sent in sentence_list:
    for word in word_tokenize(sent):
        if word in word_frequencies.keys():
            if len(sent.split(' ')) < 30:
                if sent not in sentence_scores.keys():
                    sentence_scores[sent] = word_frequencies[word]
                else:
                    sentence_scores[sent] += word_frequencies[word]

sentence_scores
# Out:
# {'سادسا': 0.1111111111111111,
#  'الحياة': 0.1111111111111111,
#  'الفنية': 0.1111111111111111,
#  'العمارة': 1.0,
#  'بلغ': 0.1111111111111111,
#  'الرومـان': 1.7777777777777777,
#  'فـي': 2.7777777777777777,
#  'درجـة': 0.1111111111111111,
#  'كبيرة': 0.1111111111111111,
#  'الاتقان': 0.1111111111111111,
#  'أصبـح': 0.1111111111111111,
#  'فـن': 1.7777777777777777,
#  'الـعمـارة': 0.1111111111111111,
#  'الرومانـي': 1.7777777777777777,
#  'هـو': 0.1111111111111111,
#  'أهـم': 0.4444444444444444,
#  'مظهر': 0.1111111111111111,
#  'فنى': 0.1111111111111111,
#  'للدولة': 0.1111111111111111,
#  'الرومانيـة': 0.1111111111111111,
#  'وجـاء': 0.1111111111111111,
#  'مزيجـا': 0.1111111111111111,
#  'مـن': 9.0,
#  'اليونانية': 0.1111111111111111,
#  'والمصرية': 0.1111111111111111,
#  'والبقايـا': 0.1111111111111111,
#  'الأثرية': 0.1111111111111111,
#  'تبـرز': 0.1111111111111111,
#  'مـدى': 0.1111111111111111,
#  'التفاعل': 0.1111111111111111,
#  'الحضـاري': 1.0,
#  'بيـن': 0.1111111111111111,
#  'الحضـارات': 0.1111111111111111,
#  'وقـد': 0.4444444444444444,
#  'أنشـأ': 0.1111111111111111,
#  'أكثـر': 0.1111111111111111,
#  'المـدن': 0.1111111111111111,
#  'روعـة': 0.1111111111111111,
#  'التاريـخ': 0.1111111111111111,
#  'وهـي': 0.1111111111111111,
#  'مدينـة': 0.1111111111111111,
#  'رومـا': 0.4444444444444444,
#  'ومـا': 0.1111111111111111,
#  'تميـزت': 0.1111111111111111,
#  'بـه': 0.1111111111111111,
#  'منشـآت': 0.1111111111111111,
#  'ضخمـة': 0.1111111111111111,
#  'كالمعابـد': 0.1111111111111111,
#  'والقصـور': 0.1111111111111111,
#  'والحمامات': 0.1111111111111111,
#  'وأقـواس': 0.1111111111111111,
#  'النصـر': 0.4444444444444444,
#  'النحت': 0.4444444444444444,
#  'مـا': 0.1111111111111111,
#  'يميـز': 0.1111111111111111,
#  'النـحـت': 0.4444444444444444,
#  'واقعيتـه': 0.1111111111111111,
#  'الشـديدة': 0.1111111111111111,
#  'خاصـة': 0.1111111111111111,
#  'نـحـت': 0.1111111111111111,
#  'التماثيل': 0.1111111111111111,
#  'الشخصية': 0.1111111111111111,
#  'مثـل': 0.4444444444444444,
#  'رأس': 0.1111111111111111,
#  'قيصـر': 0.1111111111111111,
#  'المصنـوع': 0.1111111111111111,
#  'حـجـر': 0.1111111111111111,
#  'البازلت': 0.1111111111111111,
#  'وتمثال': 0.1111111111111111,
#  'بومبي': 0.1111111111111111,
#  'أهم': 0.1111111111111111,
#  'ماتفوق': 0.1111111111111111,
#  'الرومان': 0.4444444444444444,
#  'النقوش': 0.4444444444444444,
#  'البارزة': 0.1111111111111111,
#  'الجدران': 0.1111111111111111,
#  'والأعمدة': 0.1111111111111111,
#  'واستخدموا': 0.1111111111111111,
#  'كزخارف': 0.1111111111111111,
#  'وزينة': 0.1111111111111111,
#  'أمثلتها': 0.1111111111111111,
#  'نقوش': 0.1111111111111111,
#  'عمود': 0.1111111111111111,
#  'تراجان': 0.1111111111111111,
#  'زخـارف': 0.1111111111111111,
#  'الصلصـال': 0.1111111111111111,
#  'المحـروق': 0.1111111111111111,
#  'علـى': 0.4444444444444444,
#  'جـدران': 0.4444444444444444,
#  'المعابـد': 0.1111111111111111,
#  'تجلـي': 0.1111111111111111,
#  'نحتـهـم': 0.1111111111111111,
#  'دقـة': 0.1111111111111111,
#  'العمـل': 0.1111111111111111,
#  'والتعبيـر': 0.1111111111111111,
#  'عـن': 0.1111111111111111,
#  'الشـعور': 0.1111111111111111,
#  'ومـن': 0.1111111111111111,
#  'روائـع': 0.1111111111111111,
#  'أيضـا': 0.1111111111111111,
#  'النقـوش': 0.1111111111111111,
#  'الموجـودة': 0.1111111111111111,
#  'أقـواس': 0.1111111111111111,
#  'التـي': 1.0,
#  'كـانـت': 0.1111111111111111,
#  'تقـام': 0.1111111111111111,
#  'تخليدا': 0.1111111111111111,
#  'لانتصـارات': 0.1111111111111111,
#  'القادة': 0.1111111111111111,
#  'العظـام': 0.1111111111111111,
#  'والأباطـرة': 0.1111111111111111,
#  'وأجملهـا': 0.1111111111111111,
#  'قـوس': 0.1111111111111111,
#  'الإمبراطـور': 0.1111111111111111,
#  'تيتـوس': 0.1111111111111111,
#  'التصوير': 1.0,
#  'الروماني': 0.4444444444444444,
#  'انتقل': 0.1111111111111111,
#  'فن': 0.1111111111111111,
#  'الإغريقي': 0.1111111111111111,
#  'بـانتقـال': 0.1111111111111111,
#  'الرسامين': 0.1111111111111111,
#  'الإغريق': 0.1111111111111111,
#  'روما': 0.1111111111111111,
#  'عاصمة': 0.1111111111111111,
#  'الإمبراطورية': 0.1111111111111111,
#  'وقد': 0.1111111111111111,
#  'ازدهـر': 0.1111111111111111,
#  'القديـم': 0.4444444444444444,
#  'الرسـم': 0.1111111111111111,
#  'وازداد': 0.1111111111111111,
#  'انتشـارا': 0.1111111111111111,
#  'عنـد': 0.1111111111111111,
#  'لحاجـة': 0.1111111111111111,
#  'المسكن': 0.4444444444444444,
#  'تجميل': 0.1111111111111111,
#  'حوائطـه': 0.1111111111111111,
#  'الداخـل': 0.1111111111111111,
#  'واستخدم': 0.1111111111111111,
#  'النبلاء': 0.1111111111111111,
#  'المصورين': 0.1111111111111111,
#  'الإغريـق': 0.1111111111111111,
#  'تزييـن': 0.1111111111111111,
#  'قصورهـم': 0.1111111111111111,
#  'بالرسوم': 0.1111111111111111,
#  'الملونـة': 0.1111111111111111,
#  'لتنقل': 0.1111111111111111,
#  'الطبيعة': 0.1111111111111111,
#  'والحيـاة': 0.1111111111111111,
#  'خـارج': 0.1111111111111111,
#  'داخلـه': 0.1111111111111111,
#  'كمـا': 0.4444444444444444,
#  'اهتمـوا': 0.1111111111111111,
#  'بزخرفة': 0.1111111111111111,
#  'أرضيات': 0.1111111111111111,
#  'الحجـرات': 0.1111111111111111,
#  'بلوحـات': 0.1111111111111111,
#  'الفسيفساء': 0.1111111111111111,
#  'الملـون': 0.1111111111111111,
#  'تحمـل': 0.1111111111111111,
#  'مناظـر': 0.1111111111111111,
#  'مـعبـرة': 0.1111111111111111,
#  'التواصل': 0.1111111111111111,
#  'الفنى': 0.1111111111111111,
#  'أقام': 0.1111111111111111,
#  'بالإسكندرية': 0.1111111111111111,
#  'العديد': 0.1111111111111111,
#  'المنشآت': 0.1111111111111111,
#  'المعمارية': 0.1111111111111111,
#  'والتي': 0.1111111111111111,
#  'تأثرت': 0.1111111111111111,
#  'بالحضـارة': 0.1111111111111111,
#  'الإغريقية': 0.1111111111111111,
#  'والمصريـة': 0.1111111111111111,
#  'البوابـات': 0.1111111111111111,
#  'والمسارح': 0.1111111111111111,
#  'والمعابـد': 0.1111111111111111,
#  'تأثـر': 0.1111111111111111,
#  'بالنحـت': 0.1111111111111111,
#  'المصـرى': 0.1111111111111111,
#  'لاحـظ': 0.1111111111111111,
#  'الصـورة': 0.1111111111111111,
#  'أمـامـك': 0.1111111111111111,
#  'لتتعرف': 0.1111111111111111,
#  'عليهـا': 0.1111111111111111,
#  'وهكذا': 0.1111111111111111,
#  'كانت': 0.1111111111111111,
#  'الحضارة': 0.1111111111111111,
#  'المصرية': 0.1111111111111111,
#  'القديمـة': 0.1111111111111111,
#  'رمـزا': 0.1111111111111111,
#  'للتواصل': 0.1111111111111111,
#  'حضـارات': 0.1111111111111111,
#  'الـعـالـم': 0.1111111111111111,
#  'وأحـد': 0.1111111111111111,
#  'مـعـالـم': 0.1111111111111111,
#  'التبادل': 0.1111111111111111,
#  'الثقافي': 0.1111111111111111,
#  'والفنـي': 0.1111111111111111,
#  'والدينـي': 0.1111111111111111,
#  'مـع': 0.1111111111111111,
#  'شـعـوبـه': 0.1111111111111111,
#  'خـلال': 0.1111111111111111,
#  'عمليـات': 0.1111111111111111,
#  'الأخـذ': 0.1111111111111111,
#  'والعطـاء': 0.1111111111111111,
#  'والتأثير': 0.1111111111111111,
#  'والتأثـر': 0.1111111111111111,
#  'فهـل': 0.1111111111111111,
#  'يمكـن': 0.1111111111111111,
#  'لمصـر': 0.1111111111111111,
#  'إعادة': 0.1111111111111111,
#  'هـذا': 0.1111111111111111,
#  'الـدور': 0.1111111111111111,
#  'الريـادي': 0.1111111111111111,
#  'جديد': 0.1111111111111111}

# %%
# Step 6: Get the top sentences based on scores
summary_sentences = heapq.nlargest(7, sentence_scores, key=sentence_scores.get)

summary = ' '.join(summary_sentences)
print(summary)
# Out:
# مـن فـي الرومـان فـن الرومانـي العمارة الحضـاري

# %%
import re
from pyarabic.araby import tokenize
from pyarabic.araby import strip_tashkeel
from nltk.corpus import stopwords
from nltk.stem import ISRIStemmer
import heapq

article_text = re.sub(r'\n', ' ', article_text)
article_text = re.sub(r'\s+', ' ', article_text)

formatted_article_text = re.sub('[^\u0621-\u064A\u0660-\u0669 ]', ' ', article_text)
formatted_article_text = re.sub(r'\s+', ' ', formatted_article_text)

# # Step 2: Tokenize sentences using pyarabic.araby.tokenize()
# sentence_list = tokenize(article_text)
sentence_list = nltk.sent_tokenize(article_text)

# Step 3: Set Arabic stopwords
stopwords = stopwords.words('arabic') + ['هذا', 'هذه', 'هؤلاء']  # Add additional stopwords if needed

# Step 4: Apply additional preprocessing techniques
formatted_article_text = strip_tashkeel(formatted_article_text)

# Step 5: Stemming
stemmer = ISRIStemmer()
stemmed_words = [stemmer.stem(word) for word in tokenize(formatted_article_text)]

# Step 6: Calculate word frequencies
word_frequencies = {}
for word in stemmed_words:
    if word not in stopwords:
        if word not in word_frequencies.keys():
            word_frequencies[word] = 1
        else:
            word_frequencies[word] += 1

# Step 7: Calculate sentence scores
maximum_frequency = max(word_frequencies.values())
for word in word_frequencies.keys():
    word_frequencies[word] = (word_frequencies[word] / maximum_frequency)

sentence_scores = {}
for sent in sentence_list:
    sent_words = tokenize(strip_tashkeel(sent))
    stemmed_sent_words = [stemmer.stem(word) for word in sent_words]
    for word in stemmed_sent_words:
        if word in word_frequencies.keys():
            if len(sent.split(' ')) < 30:
                if sent not in sentence_scores.keys():
                    sentence_scores[sent] = word_frequencies[word]
                else:
                    sentence_scores[sent] += word_frequencies[word]

# Step 8: Get the top sentences based on scores
summary_sentences = heapq.nlargest(30, sentence_scores, key=sentence_scores.get)

summary = ' '.join(summary_sentences)
print(summary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 16
#      12 formatted_article_text = re.sub(r'\s+', ' ', formatted_article_text)
#      14 # # Step 2: Tokenize sentences using pyarabic.araby.tokenize()
#      15 # sentence_list = tokenize(article_text)
# ---> 16 sentence_list = nltk.sent_tokenize(article_text)
#      18 # Step 3: Set Arabic stopwords
#      19 stopwords = stopwords.words('arabic') + ['هذا', 'هذه', 'هؤلاء']  # Add additional stopwords if needed
#
# NameError: name 'nltk' is not defined

# %%
article_text = "سادسا: الحياة الفنية:\nا. العمارة:\nبلغ الرومـان فـي العمارة درجـة كبيرة من الاتقان، حتى أصبـح فـن الـعمـارة الرومانـي هـو أهـم مظهر فنى للدولة الرومانيـة وجـاء مزيجـا مـن العمارة اليونانية والمصرية، والبقايـا الأثرية حتى الآن تبـرز مـدى التفاعل الحضـاري بيـن الحضـارات، وقـد أنشـأ الرومـان أكثـر المـدن روعـة فـي التاريـخ وهـي مدينـة رومـا، ومـا تميـزت بـه مـن منشـآت ضخمـة كالمعابـد والقصـور والحمامات\nوأقـواس النصـر.\n.. النحت:\nمـن أهـم مـا يميـز فـن النـحـت الرومانـي واقعيتـه الشـديدة خاصـة فـي نـحـت التماثيل الشخصية، مثـل رأس قيصـر المصنـوع مـن حـجـر البازلت وتمثال\"بومبي\". كان من أهم ماتفوق فيه الرومان النقوش البارزة على الجدران والأعمدة، واستخدموا هذه النقوش كزخارف وزينة ومن أمثلتها: نقوش عمود تراجان.\nزخـارف الصلصـال المحـروق علـى جـدران المعابـد، وقـد تجلـي فـي نحتـهـم دقـة العمـل والتعبيـر عـن الشـعور. ومـن روائـع فـن النـحـت الرومانـي أيضـا النقـوش\\ الموجـودة علـى أقـواس النصـر التـي كـانـت تقـام تخليدا لانتصـارات القادة العظـام والأباطـرة، وأجملهـا قـوس الإمبراطـور تيتـوس.\n3. التصوير الروماني:\nانتقل فن التصوير الإغريقي إلى رومـا بـانتقـال الرسامين الإغريق إلى روما عاصمة الإمبراطورية.\nوقد ازدهـر فـن التصوير القديـم أي الرسـم وازداد انتشـارا عنـد الرومـان لحاجـة المسكن الروماني إلى تجميل حوائطـه مـن الداخـل واستخدم النبلاء الرومـان المصورين الإغريـق فـي تزييـن جـدران قصورهـم بالرسوم الملونـة لتنقل الطبيعة والحيـاة مـن خـارج المسكن إلى داخلـه؛ كمـا اهتمـوا بزخرفة أرضيات الحجـرات بلوحـات مـن الفسيفساء الملـون التـي تحمـل مناظـر مـعبـرة.\nالتواصل الفنى:\nأقام الرومان بالإسكندرية العديد من المنشآت المعمارية، والتي تأثرت بالحضـارة الإغريقية والمصريـة مثـل: البوابـات والمسارح والمعابـد، كمـا تأثـر النحت الرومانـي بالنحـت المصـرى... لاحـظ الصـورة التـي أمـامـك\nلتتعرف عليهـا… وهكذا كانت الحضارة المصرية القديمـة رمـزا للتواصل الحضـاري مع حضـارات الـعـالـم القديـم، وأحـد مـعـالـم التبادل الثقافي والفنـي والدينـي مـع شـعـوبـه مـن خـلال عمليـات الأخـذ والعطـاء والتأثير والتأثـر... فهـل يمكـن\nلمصـر إعادة هـذا الـدور الحضـاري الريـادي مـن جديد؟\n"

df_summarizer(article_text)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 article_text = "سادسا: الحياة الفنية:\nا. العمارة:\nبلغ الرومـان فـي العمارة درجـة كبيرة من الاتقان، حتى أصبـح فـن الـعمـارة الرومانـي هـو أهـم مظهر فنى للدولة الرومانيـة وجـاء مزيجـا مـن العمارة اليونانية والمصرية، والبقايـا الأثرية حتى الآن تبـرز مـدى التفاعل الحضـاري بيـن الحضـارات، وقـد أنشـأ الرومـان أكثـر المـدن روعـة فـي التاريـخ وهـي مدينـة رومـا، ومـا تميـزت بـه مـن منشـآت ضخمـة كالمعابـد والقصـور والحمامات\nوأقـواس النصـر.\n.. النحت:\nمـن أهـم مـا يميـز فـن النـحـت الرومانـي واقعيتـه الشـديدة خاصـة فـي نـحـت التماثيل الشخصية، مثـل رأس قيصـر المصنـوع مـن حـجـر البازلت وتمثال\"بومبي\". كان من أهم ماتفوق فيه الرومان النقوش البارزة على الجدران والأعمدة، واستخدموا هذه النقوش كزخارف وزينة ومن أمثلتها: نقوش عمود تراجان.\nزخـارف الصلصـال المحـروق علـى جـدران المعابـد، وقـد تجلـي فـي نحتـهـم دقـة العمـل والتعبيـر عـن الشـعور. ومـن روائـع فـن النـحـت الرومانـي أيضـا النقـوش\\ الموجـودة علـى أقـواس النصـر التـي كـانـت تقـام تخليدا لانتصـارات القادة العظـام والأباطـرة، وأجملهـا قـوس الإمبراطـور تيتـوس.\n3. التصوير الروماني:\nانتقل فن التصوير الإغريقي إلى رومـا بـانتقـال الرسامين الإغريق إلى روما عاصمة الإمبراطورية.\nوقد ازدهـر فـن التصوير القديـم أي الرسـم وازداد انتشـارا عنـد الرومـان لحاجـة المسكن الروماني إلى تجميل حوائطـه مـن الداخـل واستخدم النبلاء الرومـان المصورين الإغريـق فـي تزييـن جـدران قصورهـم بالرسوم الملونـة لتنقل الطبيعة والحيـاة مـن خـارج المسكن إلى داخلـه؛ كمـا اهتمـوا بزخرفة أرضيات الحجـرات بلوحـات مـن الفسيفساء الملـون التـي تحمـل مناظـر مـعبـرة.\nالتواصل الفنى:\nأقام الرومان بالإسكندرية العديد من المنشآت المعمارية، والتي تأثرت بالحضـارة الإغريقية والمصريـة مثـل: البوابـات والمسارح والمعابـد، كمـا تأثـر النحت الرومانـي بالنحـت المصـرى... لاحـظ الصـورة التـي أمـامـك\nلتتعرف عليهـا… وهكذا كانت الحضارة المصرية القديمـة رمـزا للتواصل الحضـاري مع حضـارات الـعـالـم القديـم، وأحـد مـعـالـم التبادل الثقافي والفنـي والدينـي مـع شـعـوبـه مـن خـلال عمليـات الأخـذ والعطـاء والتأثير والتأثـر... فهـل يمكـن\nلمصـر إعادة هـذا الـدور الحضـاري الريـادي مـن جديد؟\n"
# ----> 3 df_summarizer(article_text)
#
# Cell In[7], line 19, in df_summarizer(text)
#      16 sentence_list = tokenize(article_text)
#      18 # Step 3: Set Arabic stopwords
# ---> 19 stopwords = stopwords.words('arabic') + ['هذا', 'هذه', 'هؤلاء']  # Add additional stopwords if needed
#      21 # Step 4: Apply additional preprocessing techniques
#      22 formatted_article_text = strip_tashkeel(formatted_article_text)
#
# UnboundLocalError: local variable 'stopwords' referenced before assignment

# %%
from summa.summarizer import summarize
# Out:
# 'وأثناء الحصار كانت تجرى محادثات لدخول أهل بيت المقدس في الصلح مع المسلمين، فلم يجد بطريرك بيت المقدس أمامه سوى المصالحة، ولكنه اشترط أن يتم الصلح مع الخليفة عمر بن الخطاب بنفسه وذلك لما للمدينة من قدسية وأهمية دينية كبيرة، فأرسل عمرو بن العاص بهذه الأخبار إلى الخليفة بالمدينة النبوية، وقال له في رسالته: "إني أعالج حربا كؤدًا صدومًا وبلادا ادخرت لك فلك رأيك" فكان أول خروج للخليفة من المدينة بعد موت رسول الله ، هذا الخروج الأجل لكي يفتح بيت المقدس .'

# %%
summarize(article_text, language='arabic')
# Out:
# 'العمارة: بلغ الرومـان فـي العمارة درجـة كبيرة من الاتقان، حتى أصبـح فـن الـعمـارة الرومانـي هـو أهـم مظهر فنى للدولة الرومانيـة وجـاء مزيجـا مـن العمارة اليونانية والمصرية، والبقايـا الأثرية حتى الآن تبـرز مـدى التفاعل الحضـاري بيـن الحضـارات، وقـد أنشـأ الرومـان أكثـر المـدن روعـة فـي التاريـخ وهـي مدينـة رومـا، ومـا تميـزت بـه مـن منشـآت ضخمـة كالمعابـد والقصـور والحمامات وأقـواس النصـر.\nوقد ازدهـر فـن التصوير القديـم أي الرسـم وازداد انتشـارا عنـد الرومـان لحاجـة المسكن الروماني إلى تجميل حوائطـه مـن الداخـل واستخدم النبلاء الرومـان المصورين الإغريـق فـي تزييـن جـدران قصورهـم بالرسوم الملونـة لتنقل الطبيعة والحيـاة مـن خـارج المسكن إلى داخلـه؛ كمـا اهتمـوا بزخرفة أرضيات الحجـرات بلوحـات مـن الفسيفساء الملـون التـي تحمـل مناظـر مـعبـرة.'

# %%
"الاهرامات الجيزه الهضبه الجنوبيه للمجمع اليمين للشمال الهرم الاكبر هرم خوفو هرم خفرع اصغر الاهرامات الثلاثة هرم منقرع مصطبة فرعون فى سقاره الاهرامات المصريه اكبر الابنيه القديمه وتشكل واحده اقوى رموز الحضاره المصريه القديمه واتبنيت معظم الاهرامات المصريه خلال فترات المملكة القديمة المملكة الوسطانية ايد قدماء المصريين فى الضفه الغربيه لنهر النيل علشان كانت بتعتبر ارض الميتين ايمانهم السودان توجد اهرامات أقدم الاهرامات المصرية لكنها اصغر التطور التاريخى فى الفتره المبكره التاريخ المصرى الوسائل الكافيه الدفن بيتم فى مبنى يشبه الهياكل المعروفه بالمصاطب زى مصطبة فرعون فى سقاره اول هرم مصرى موثق تاريخيا يرجع للمهندس المعمارى امحوتب عدد وموقع الاهرامات عدد الهياكل الهرميه فى مصر النهارده هرم ليستة أهرامات مصر مراجع الاهرامات المصريه تصنيف تاريخ مصر العمرانى"

# %%
import re
import pandas as pd
from pyarabic.araby import tokenize
from pyarabic.araby import strip_tashkeel
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import ISRIStemmer
import heapq
import nltk

def df_summarizer(text):
    article_text = re.sub(r'\n', ' ', text)
    article_text = re.sub(r'\s+', ' ', article_text)

    formatted_article_text = re.sub('[^\u0621-\u064A\u0660-\u0669 ]', ' ', article_text)
    formatted_article_text = re.sub(r'\s+', ' ', formatted_article_text)

    # Set the appropriate language code for Arabic stopwords
    stopwords = nltk.corpus.stopwords.words('arabic')

    word_frequencies = {}
    for word in nltk.word_tokenize(formatted_article_text):
        if word not in stopwords:
            if word not in word_frequencies.keys():
                word_frequencies[word] = 1
            else:
                word_frequencies[word] += 1
                
    sentence_list = nltk.sent_tokenize(article_text)

    maximum_frequency = max(word_frequencies.values())
    for word in word_frequencies.keys():
        word_frequencies[word] = (word_frequencies[word] / maximum_frequency)
    #     print(word_frequencies)

    sentence_scores = {}
    for sent in sentence_list:
        for word in word_tokenize(sent):
            if word in word_frequencies.keys():
                if len(sent.split(' ')) < 30:
                    if sent not in sentence_scores.keys():
                        sentence_scores[sent] = word_frequencies[word]
                    else:
                        sentence_scores[sent] += word_frequencies[word]
                        
    # Step 6: Get the top sentences based on scores
    summary_sentences = heapq.nlargest(7, sentence_scores, key=sentence_scores.get)

    summary = ' '.join(summary_sentences)
    return summary

# %%
df = pd.read_json("../validation_dataset/labeled_validation_dataset.jsonl", lines=True)
df.head()
# Out:
#    example_id                                          paragraph  \
# 0           0  وتحت عنوان من الكارثة إلى التحدى يبدأ الكاتب ع...
# 1           1  ولم يعترف دبلوماسيو هاتين الدولتين بالعريضة ال...
# 2           2  قامت ولاية حلب بعد اعلان الجنرال الفرنسي هنري ...
# 3           3  دولة مصر العربيه هي ليست اي دوله وليست اي شعب ...
# 4           4  السوريون يصرون على استقلال بلادهم : و مثلما رف...
#
#                                              summary
# 0  يبدأ الكاتب عرض الكتاب الرابع تحت عنوان من الك...
# 1  دبلوماسيو الدولتين لم يعترفوا بالعريضة التي قا...
# 2  أعلن غورو الانتداب الفرنسي على سوريا لكي يعاقب...
# 3  مصر هي أم البلاد، وقائدة العرب؛ فهي أرض بلاد ا...
# 4  الشعب السوري يصر على استقلال بلدهم من السيطرة ...

# %%
article_text = "سادسا: الحياة الفنية:\nا. العمارة:\nبلغ الرومـان فـي العمارة درجـة كبيرة من الاتقان، حتى أصبـح فـن الـعمـارة الرومانـي هـو أهـم مظهر فنى للدولة الرومانيـة وجـاء مزيجـا مـن العمارة اليونانية والمصرية، والبقايـا الأثرية حتى الآن تبـرز مـدى التفاعل الحضـاري بيـن الحضـارات، وقـد أنشـأ الرومـان أكثـر المـدن روعـة فـي التاريـخ وهـي مدينـة رومـا، ومـا تميـزت بـه مـن منشـآت ضخمـة كالمعابـد والقصـور والحمامات\nوأقـواس النصـر.\n.. النحت:\nمـن أهـم مـا يميـز فـن النـحـت الرومانـي واقعيتـه الشـديدة خاصـة فـي نـحـت التماثيل الشخصية، مثـل رأس قيصـر المصنـوع مـن حـجـر البازلت وتمثال\"بومبي\". كان من أهم ماتفوق فيه الرومان النقوش البارزة على الجدران والأعمدة، واستخدموا هذه النقوش كزخارف وزينة ومن أمثلتها: نقوش عمود تراجان.\nزخـارف الصلصـال المحـروق علـى جـدران المعابـد، وقـد تجلـي فـي نحتـهـم دقـة العمـل والتعبيـر عـن الشـعور. ومـن روائـع فـن النـحـت الرومانـي أيضـا النقـوش\\ الموجـودة علـى أقـواس النصـر التـي كـانـت تقـام تخليدا لانتصـارات القادة العظـام والأباطـرة، وأجملهـا قـوس الإمبراطـور تيتـوس.\n3. التصوير الروماني:\nانتقل فن التصوير الإغريقي إلى رومـا بـانتقـال الرسامين الإغريق إلى روما عاصمة الإمبراطورية.\nوقد ازدهـر فـن التصوير القديـم أي الرسـم وازداد انتشـارا عنـد الرومـان لحاجـة المسكن الروماني إلى تجميل حوائطـه مـن الداخـل واستخدم النبلاء الرومـان المصورين الإغريـق فـي تزييـن جـدران قصورهـم بالرسوم الملونـة لتنقل الطبيعة والحيـاة مـن خـارج المسكن إلى داخلـه؛ كمـا اهتمـوا بزخرفة أرضيات الحجـرات بلوحـات مـن الفسيفساء الملـون التـي تحمـل مناظـر مـعبـرة.\nالتواصل الفنى:\nأقام الرومان بالإسكندرية العديد من المنشآت المعمارية، والتي تأثرت بالحضـارة الإغريقية والمصريـة مثـل: البوابـات والمسارح والمعابـد، كمـا تأثـر النحت الرومانـي بالنحـت المصـرى... لاحـظ الصـورة التـي أمـامـك\nلتتعرف عليهـا… وهكذا كانت الحضارة المصرية القديمـة رمـزا للتواصل الحضـاري مع حضـارات الـعـالـم القديـم، وأحـد مـعـالـم التبادل الثقافي والفنـي والدينـي مـع شـعـوبـه مـن خـلال عمليـات الأخـذ والعطـاء والتأثير والتأثـر... فهـل يمكـن\nلمصـر إعادة هـذا الـدور الحضـاري الريـادي مـن جديد؟\n"

df_summarizer(article_text)
# Out:
# '.. النحت: مـن أهـم مـا يميـز فـن النـحـت الرومانـي واقعيتـه الشـديدة خاصـة فـي نـحـت التماثيل الشخصية، مثـل رأس قيصـر المصنـوع مـن حـجـر البازلت وتمثال"بومبي". ومـن روائـع فـن النـحـت الرومانـي أيضـا النقـوش\\ الموجـودة علـى أقـواس النصـر التـي كـانـت تقـام تخليدا لانتصـارات القادة العظـام والأباطـرة، وأجملهـا قـوس الإمبراطـور تيتـوس. زخـارف الصلصـال المحـروق علـى جـدران المعابـد، وقـد تجلـي فـي نحتـهـم دقـة العمـل والتعبيـر عـن الشـعور. التصوير الروماني: انتقل فن التصوير الإغريقي إلى رومـا بـانتقـال الرسامين الإغريق إلى روما عاصمة الإمبراطورية. كان من أهم ماتفوق فيه الرومان النقوش البارزة على الجدران والأعمدة، واستخدموا هذه النقوش كزخارف وزينة ومن أمثلتها: نقوش عمود تراجان. سادسا: الحياة الفنية: ا.'

# %%
df["summary_gen"] = df["paragraph"].apply(df_summarizer)
df.head()
# Out:
#    example_id                                          paragraph  \
# 0           0  وتحت عنوان من الكارثة إلى التحدى يبدأ الكاتب ع...
# 1           1  ولم يعترف دبلوماسيو هاتين الدولتين بالعريضة ال...
# 2           2  قامت ولاية حلب بعد اعلان الجنرال الفرنسي هنري ...
# 3           3  دولة مصر العربيه هي ليست اي دوله وليست اي شعب ...
# 4           4  السوريون يصرون على استقلال بلادهم : و مثلما رف...
#
#                                              summary  \
# 0  يبدأ الكاتب عرض الكتاب الرابع تحت عنوان من الك...
# 1  دبلوماسيو الدولتين لم يعترفوا بالعريضة التي قا...
# 2  أعلن غورو الانتداب الفرنسي على سوريا لكي يعاقب...
# 3  مصر هي أم البلاد، وقائدة العرب؛ فهي أرض بلاد ا...
# 4  الشعب السوري يصر على استقلال بلدهم من السيطرة ...
#
#                                          summary_gen
# 0
# 1  فما إن أعلن عن نبأ تنحية السلطان حتى أدان زعيم...
# 2
# 3
# 4

# %%
for i in range(6):
    print(f"summary_gen {i}: ", df.loc[i, "summary_gen"])
# Out:
# summary_gen 0:
# summary_gen 1:  فما إن أعلن عن نبأ تنحية السلطان حتى أدان زعيم الحركة الوطنية علال الفاسي عبر إذاعة القاهرة في برنامج صوت العرب إبعاد السلطان هو وعائلته عن الوطن . ومنذ 21 أغسطس 1953، أظهرت 15 دولة عربية آسيوية عضو في هيئة الأمم المتحدة انشغالها بمستقبل الاستقرار السياسي بشمال إفريقيا بعد عملية نفي محمد بن يوسف . ولم يعترف دبلوماسيو هاتين الدولتين بالعريضة التي وقعها الأعيان ، إذ اعتبروها محاولة فقط من سلطات الحماية لإجبار السلطان على قبول مخططاتها وذلك بالتوقيع على الظهائر . ثم أعلنت العريضة " أحقية السيادة التي يتمتع بها المهدي بن إسماعيل على المنطقة الخليفية "، وذلك تحت إمرة سلطة فرانكو . وقد استقبلت عملية تنصيب سلطان جديد على المغرب بإسبانيا بنوع من الاستياء ، إذ اعتبرته سلطات مدريد إعلانا لنوع من العداء ضدها . أما معارضة الدول العربية والآسيوية ، فإنها تمثلت في شنها لحملة شرسة عبر الصحافة والإذاعة ضد الإجراء الفرنسي . وأما جامعة الدول العربية ، فقد عبرت عن تخوفاتها إزاء تطورات القضية المغربية وبدأت في الإلحاح على ضرورة استقلال المغرب .
# summary_gen 2:
# summary_gen 3:
# summary_gen 4:
# summary_gen 5:  وقال اللواء الركن الخضر أن الجيش الكويتي يستفيد دائما من خبرة ومهارات الجيش المصري وفي كافة أوجه التعاون العسكري .

# %%
import nltk
import re
import string
from gensim.models import Word2Vec
from nltk.tokenize import sent_tokenize as nlkt_sent_tokenize
from nltk.tokenize import word_tokenize as nlkt_word_tokenize
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from nltk.corpus import stopwords
import numpy as np
from scipy.spatial.distance import cosine

# %%
#Calculates cosine similarity
def similarity(v1, v2):
    score = 0.0
    if np.count_nonzero(v1) != 0 and np.count_nonzero(v2) != 0:
        score = ((1 - cosine(v1, v2)) + 1) / 2
    return score

# %%
def sent_tokenize(text):
    sents = nlkt_sent_tokenize(text)
    sents_filtered = []
    for s in sents:
        sents_filtered.append(s)
    return sents_filtered

# %%
def delete_links(input_text):
    pettern  = r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))'''
    out_text = re.sub(pettern, ' ', input_text)
    return out_text

def delete_repeated_characters(input_text):
    pattern  = r'(.)\1{2,}'
    out_text = re.sub(pattern, r"\1\1", input_text)
    return out_text



def cleanup_sentences(text):
    text = re.sub(r'\n', ' ', text)
    stop_words = set(stopwords.words('arabic'))
    sentences = sent_tokenize(text)
    sentences_cleaned = []
    for sent in sentences:
        sent = sent.replace('/', '')
        sent = sent.replace('\n', '')
        sent = re.sub(r'\n', ' ', sent)
        sentences_cleaned.append(preprocess_arabic_text(sent))
    return sentences_cleaned

# %%
def get_tf_idf(sentences):
    vectorizer = CountVectorizer()
    sent_word_matrix = vectorizer.fit_transform(sentences)

    transformer = TfidfTransformer(norm=None, sublinear_tf=False, smooth_idf=False)
    tfidf = transformer.fit_transform(sent_word_matrix)
    tfidf = tfidf.toarray()

    centroid_vector = tfidf.sum(0)
    centroid_vector = np.divide(centroid_vector, centroid_vector.max())

    feature_names = vectorizer.get_feature_names_out()

    relevant_vector_indices = np.where(centroid_vector > 0.3)[0]

    word_list = list(np.array(feature_names)[relevant_vector_indices])
    return word_list

# %%
#Populate word vector with all embeddings.
#This word vector is a look up table that is used
#for getting the centroid and sentences embedding representation.
def word_vectors_cache(sentences, embedding_model):
    word_vectors = dict()
    for sent in sentences:
        words = nlkt_word_tokenize(sent)
        for w in words:
            word_vectors.update({w: embedding_model.wv[w]})
    return word_vectors

# %%
# Sentence embedding representation with sum of word vectors
def build_embedding_representation(words, word_vectors, embedding_model):
    embedding_representation = np.zeros(embedding_model.vector_size, dtype="float32")
    word_vectors_keys = set(word_vectors.keys())
    count = 0
    for w in words:
        if w in word_vectors_keys:
            embedding_representation = embedding_representation + word_vectors[w]
            count += 1
    if count != 0:
        embedding_representation = np.divide(embedding_representation, count)
    return embedding_representation

# %%
def summarize(text, emdedding_model):
    raw_sentences = sent_tokenize(text)
    clean_sentences = cleanup_sentences(text)
#     for i, s in enumerate(raw_sentences):
#         print(i, s)
#     for i, s in enumerate(clean_sentences):
#         print(i, s)
    centroid_words = get_tf_idf(clean_sentences)
#     print(len(centroid_words), centroid_words)
    word_vectors = word_vectors_cache(clean_sentences, emdedding_model)
    #Centroid embedding representation
    centroid_vector = build_embedding_representation(centroid_words, word_vectors, emdedding_model)
    sentences_scores = []
    for i in range(len(clean_sentences)):
        scores = []
        words = clean_sentences[i].split()

        #Sentence embedding representation
        sentence_vector = build_embedding_representation(words, word_vectors, emdedding_model)

        #Cosine similarity between sentence embedding and centroid embedding
        score = similarity(sentence_vector, centroid_vector)
        sentences_scores.append((i, raw_sentences[i], score, sentence_vector))
    sentence_scores_sort = sorted(sentences_scores, key=lambda el: el[2], reverse=True)
#     for s in sentence_scores_sort:
#         print(s[0], s[1], s[2])
    count = 0
    sentences_summary = []
    #Handle redundancy
    for s in sentence_scores_sort:
        if count > 100:
            break
        include_flag = True
        for ps in sentences_summary:
            sim = similarity(s[3], ps[3])
            if sim > 0.95:
                include_flag = False
        if include_flag:
            sentences_summary.append(s)
            count += len(s[1].split())

        sentences_summary = sorted(sentences_summary, key=lambda el: el[0], reverse=False)

    summary = " ".join([s[1] for s in sentences_summary])
#     print(summary)
    return summary

# %%
def summarizer(text):
    clean_sentences = cleanup_sentences(text)
    words = []
    for sent in clean_sentences:
        words.append(nlkt_word_tokenize(sent))
    model = Word2Vec(words, min_count=1, sg = 1)
    return summarize(text, model)

text = """وتحت عنوان من الكارثة إلى التحدى يبدأ الكاتب عرض الكتاب الرابع ، حيث يوضح كيف كانت إسرائيل فرحة بنصرها عام 67 وأنها ارتاحت لاعتقادها بأن هناك وقتا طويلا وطويلا جدا قبل أن يفيق العرب من صدمة 67، وكيف أن القوات الجوية للجمهورية العربية المتحدة قد فاجأتها بعد شهر واحد من نهاية حرب 67 بهجوم جوى عنيف على مواقعها فى سيناء وكان هذا إعلانا عن بداية حرب من نوع جديد هى حرب الاستنزاف التى استمرت حتى تم وقف إطلاق النار بين الطرفين فى 8 أغسطس 1970، ثم وفاة عبدالناصر وتولى أنور السادات حكم مصر واستعداده للحرب . ويتعرض الكاتب أيضا وبصورة سريعة لفلسطين والأردن وسوريا قبل أن ينتقل إلى الكتاب الخامس عن حرب أكتوبر ، حيث يعرض الخطط والاستعدادات المصرية ثم الاستعدادات الإسرائيلية ثم يبدأ بعرض وقائع الحرب بداية من الضربة الجوية وانهيار خط بارليف واختراقه ، ويتوقف الكاتب عند يوم 8 أكتوبر ، ويقول : إن هذا اليوم كان اسوأ هزيمة فى تاريخ الجيش الإسرائيلى ثم ينتقل بنا المؤلف إلى الجبهة السورية ثم يعود ثانية إلى يوميات الحرب حتى 7 9 أكتوبر إلى 9 13 أكتوبر ثم 14 أكتوبر ، ثم يعرض للثغرة أو ما عرف بعملية المزرعة الصينية يوم 16 و 15 أكتوبر والمساعدات الأمريكية الضخمة لإسرائيل ، ثم بداية الضغوط السياسية على الرئيس أنور السادات من 17 19 أكتوبر ثم ينتقل الكاتب للأحداث التى جرت من 17 20 أكتوبر وإعفاء الفريق الشاذلى من منصبه كرئيس لأركان القوات المسلحة المصرية ، وتولى الفريق الجمسى بدلا منه ثم الاتجاه إلى الموافقة على طلب وقف إطلاق النار والخلاف مع سوريا بشأن هذا الأمر ، ثم بداية الهجوم الإسرائيلى من 19 إلى 22 أكتوبر على الضفة الغربية لقناة السويس والعمليات النهائية فى سوريا 14 23 أكتوبر ، وكيف أن الملك حسين قرر دخول الحرب ضد إسرائيل يوم 9 أكتوبر ، ثم يعرض الكاتب المعركة الخاصة بالاستيلاء على مدينة السويس من 23 أكتوبر إلى 25 أكتوبر ثم تطورات هذه المعركة ، وكيف أنه مع حلول يوم السابع والعشرين من أكتوبر كان الإسرائيليون قد أسروا نحو ثمانية آلاف فرد من القوات المصرية ، أغلبهم من وحدات الإمداد والتموين ."""

print(summarizer(text))
# Out:
# ويتعرض الكاتب أيضا وبصورة سريعة لفلسطين والأردن وسوريا قبل أن ينتقل إلى الكتاب الخامس عن حرب أكتوبر ، حيث يعرض الخطط والاستعدادات المصرية ثم الاستعدادات الإسرائيلية ثم يبدأ بعرض وقائع الحرب بداية من الضربة الجوية وانهيار خط بارليف واختراقه ، ويتوقف الكاتب عند يوم 8 أكتوبر ، ويقول : إن هذا اليوم كان اسوأ هزيمة فى تاريخ الجيش الإسرائيلى ثم ينتقل بنا المؤلف إلى الجبهة السورية ثم يعود ثانية إلى يوميات الحرب حتى 7 9 أكتوبر إلى 9 13 أكتوبر ثم 14 أكتوبر ، ثم يعرض للثغرة أو ما عرف بعملية المزرعة الصينية يوم 16 و 15 أكتوبر والمساعدات الأمريكية الضخمة لإسرائيل ، ثم بداية الضغوط السياسية على الرئيس أنور السادات من 17 19 أكتوبر ثم ينتقل الكاتب للأحداث التى جرت من 17 20 أكتوبر وإعفاء الفريق الشاذلى من منصبه كرئيس لأركان القوات المسلحة المصرية ، وتولى الفريق الجمسى بدلا منه ثم الاتجاه إلى الموافقة على طلب وقف إطلاق النار والخلاف مع سوريا بشأن هذا الأمر ، ثم بداية الهجوم الإسرائيلى من 19 إلى 22 أكتوبر على الضفة الغربية لقناة السويس والعمليات النهائية فى سوريا 14 23 أكتوبر ، وكيف أن الملك حسين قرر دخول الحرب ضد إسرائيل يوم 9 أكتوبر ، ثم يعرض الكاتب المعركة الخاصة بالاستيلاء على مدينة السويس من 23 أكتوبر إلى 25 أكتوبر ثم تطورات هذه المعركة ، وكيف أنه مع حلول يوم السابع والعشرين من أكتوبر كان الإسرائيليون قد أسروا نحو ثمانية آلاف فرد من القوات المصرية ، أغلبهم من وحدات الإمداد والتموين .

# %%
from rouge import Rouge
# Instantiate the Rouge evaluator
rouge = Rouge()

# Define the method to calculate ROUGE-L
def calculate_rouge(row):
    reference_summary = row['summary']
    system_summary = row['summary_gen']
    scores = rouge.get_scores(system_summary, reference_summary)
    rouge_l = scores[0]['rouge-l']
    return rouge_l["r"]

# %%
import pandas as pd

# %%
df = pd.read_json('../validation_dataset/labeled_validation_dataset.jsonl', lines=True)
df.head()
# Out:
#    example_id                                          paragraph  \
# 0           0  وتحت عنوان من الكارثة إلى التحدى يبدأ الكاتب ع...
# 1           1  ولم يعترف دبلوماسيو هاتين الدولتين بالعريضة ال...
# 2           2  قامت ولاية حلب بعد اعلان الجنرال الفرنسي هنري ...
# 3           3  دولة مصر العربيه هي ليست اي دوله وليست اي شعب ...
# 4           4  السوريون يصرون على استقلال بلادهم : و مثلما رف...
#
#                                              summary
# 0  يبدأ الكاتب عرض الكتاب الرابع تحت عنوان من الك...
# 1  دبلوماسيو الدولتين لم يعترفوا بالعريضة التي قا...
# 2  أعلن غورو الانتداب الفرنسي على سوريا لكي يعاقب...
# 3  مصر هي أم البلاد، وقائدة العرب؛ فهي أرض بلاد ا...
# 4  الشعب السوري يصر على استقلال بلدهم من السيطرة ...

# %%
df["summary_gen"] = df["paragraph"].apply(summarize_arabic_text)

# %%
df.paragraph[0]
# Out:
# 'وتحت عنوان من الكارثة إلى التحدى يبدأ الكاتب عرض الكتاب الرابع ، حيث يوضح كيف كانت إسرائيل فرحة بنصرها عام 67 وأنها ارتاحت لاعتقادها بأن هناك وقتا طويلا وطويلا جدا قبل أن يفيق العرب من صدمة 67، وكيف أن القوات الجوية للجمهورية العربية المتحدة قد فاجأتها بعد شهر واحد من نهاية حرب 67 بهجوم جوى عنيف على مواقعها فى سيناء وكان هذا إعلانا عن بداية حرب من نوع جديد هى حرب الاستنزاف التى استمرت حتى تم وقف إطلاق النار بين الطرفين فى 8 أغسطس 1970، ثم وفاة عبدالناصر وتولى أنور السادات حكم مصر واستعداده للحرب . ويتعرض الكاتب أيضا وبصورة سريعة لفلسطين والأردن وسوريا قبل أن ينتقل إلى الكتاب الخامس عن حرب أكتوبر ، حيث يعرض الخطط والاستعدادات المصرية ثم الاستعدادات الإسرائيلية ثم يبدأ بعرض وقائع الحرب بداية من الضربة الجوية وانهيار خط بارليف واختراقه ، ويتوقف الكاتب عند يوم 8 أكتوبر ، ويقول : إن هذا اليوم كان اسوأ هزيمة فى تاريخ الجيش الإسرائيلى ثم ينتقل بنا المؤلف إلى الجبهة السورية ثم يعود ثانية إلى يوميات الحرب حتى 7 9 أكتوبر إلى 9 13 أكتوبر ثم 14 أكتوبر ، ثم يعرض للثغرة أو ما عرف بعملية المزرعة الصينية يوم 16 و 15 أكتوبر والمساعدات الأمريكية الضخمة لإسرائيل ، ثم بداية الضغوط السياسية على الرئيس أنور السادات من 17 19 أكتوبر ثم ينتقل الكاتب للأحداث التى جرت من 17 20 أكتوبر وإعفاء الفريق الشاذلى من منصبه كرئيس لأركان القوات المسلحة المصرية ، وتولى الفريق الجمسى بدلا منه ثم الاتجاه إلى الموافقة على طلب وقف إطلاق النار والخلاف مع سوريا بشأن هذا الأمر ، ثم بداية الهجوم الإسرائيلى من 19 إلى 22 أكتوبر على الضفة الغربية لقناة السويس والعمليات النهائية فى سوريا 14 23 أكتوبر ، وكيف أن الملك حسين قرر دخول الحرب ضد إسرائيل يوم 9 أكتوبر ، ثم يعرض الكاتب المعركة الخاصة بالاستيلاء على مدينة السويس من 23 أكتوبر إلى 25 أكتوبر ثم تطورات هذه المعركة ، وكيف أنه مع حلول يوم السابع والعشرين من أكتوبر كان الإسرائيليون قد أسروا نحو ثمانية آلاف فرد من القوات المصرية ، أغلبهم من وحدات الإمداد والتموين .'

# %%
df.summary[0]
# Out:
# 'يبدأ الكاتب عرض الكتاب الرابع تحت عنوان من الكارثة إلى التحدى؛ حيث يوضح كيف كانت إسرائيل فرحة بنصرها عام 67، وكيف بدأت حرب الاستنزاف، ثم يتكلم عن وفاة عبدالناصر، وتولى أنور السادات حكم مصر، ويعرض الكاتب للخطط والاستعدادات المصرية، ثم الاستعدادات الإسرائيلية، ثم يبدأ بعرض وقائع الحرب، ويتوقف الكاتب عند يوم 8 أكتوبر، ويقول: إن هذا اليوم كان أسوأ هزيمة فى تاريخ الجيش الإسرائيلى، ثم ينتقل بنا إلى الجبهة السورية، ثم يعود ثانية إلى يوميات الحرب من  9 أكتوبر إلى 13 و 14 أكتوبر، والعمليات النهائية فى سوريا 14 إلى 23 أكتوبر، ثم يعرض الكاتب المعركة الخاصة بالاستيلاء على مدينة السويس من 23 أكتوبر إلى 25 أكتوبر، ثم تطورات هذه المعركة. '

# %%
df.summary_gen[0]
# Out:
# 'وتحت عنوان من الكارثة إلى التحدى يبدأ الكاتب عرض الكتاب الرابع ، حيث يوضح كيف كانت إسرائيل فرحة بنصرها عام 67 وأنها ارتاحت لاعتقادها بأن هناك وقتا طويلا وطويلا جدا قبل أن يفيق العرب من صدمة 67، وكيف أن القوات الجوية للجمهورية العربية المتحدة قد فاجأتها بعد شهر واحد من نهاية حرب 67 بهجوم جوى عنيف على مواقعها فى سيناء وكان هذا إعلانا عن بداية حرب من نوع جديد هى حرب الاستنزاف التى استمرت حتى تم وقف إطلاق النار بين الطرفين فى 8 أغسطس 1970، ثم وفاة عبدالناصر وتولى أنور السادات حكم مصر واستعداده للحرب . ويتعرض الكاتب أيضا وبصورة سريعة لفلسطين والأردن وسوريا قبل أن ينتقل إلى الكتاب الخامس عن حرب أكتوبر ، حيث يعرض الخطط والاستعدادات المصرية ثم الاستعدادات الإسرائيلية ثم يبدأ بعرض وقائع الحرب بداية من الضربة الجوية وانهيار خط بارليف واختراقه ، ويتوقف الكاتب عند يوم 8 أكتوبر ، ويقول : إن هذا اليوم كان اسوأ هزيمة فى تاريخ الجيش الإسرائيلى ثم ينتقل بنا المؤلف إلى الجبهة السورية ثم يعود ثانية إلى يوميات الحرب حتى 7 9 أكتوبر إلى 9 13 أكتوبر ثم 14 أكتوبر ، ثم يعرض للثغرة أو ما عرف بعملية المزرعة الصينية يوم 16 و 15 أكتوبر والمساعدات الأمريكية الضخمة لإسرائيل ، ثم بداية الضغوط السياسية على الرئيس أنور السادات من 17 19 أكتوبر ثم ينتقل الكاتب للأحداث التى جرت من 17 20 أكتوبر وإعفاء الفريق الشاذلى من منصبه كرئيس لأركان القوات المسلحة المصرية ، وتولى الفريق الجمسى بدلا منه ثم الاتجاه إلى الموافقة على طلب وقف إطلاق النار والخلاف مع سوريا بشأن هذا الأمر ، ثم بداية الهجوم الإسرائيلى من 19 إلى 22 أكتوبر على الضفة الغربية لقناة السويس والعمليات النهائية فى سوريا 14 23 أكتوبر ، وكيف أن الملك حسين قرر دخول الحرب ضد إسرائيل يوم 9 أكتوبر ، ثم يعرض الكاتب المعركة الخاصة بالاستيلاء على مدينة السويس من 23 أكتوبر إلى 25 أكتوبر ثم تطورات هذه المعركة ، وكيف أنه مع حلول يوم السابع والعشرين من أكتوبر كان الإسرائيليون قد أسروا نحو ثمانية آلاف فرد من القوات المصرية ، أغلبهم من وحدات الإمداد والتموين .'

# %%
df.head()
# Out:
#    example_id                                          paragraph  \
# 0           0  وتحت عنوان من الكارثة إلى التحدى يبدأ الكاتب ع...
# 1           1  ولم يعترف دبلوماسيو هاتين الدولتين بالعريضة ال...
# 2           2  قامت ولاية حلب بعد اعلان الجنرال الفرنسي هنري ...
# 3           3  دولة مصر العربيه هي ليست اي دوله وليست اي شعب ...
# 4           4  السوريون يصرون على استقلال بلادهم : و مثلما رف...
#
#                                              summary  \
# 0  يبدأ الكاتب عرض الكتاب الرابع تحت عنوان من الك...
# 1  دبلوماسيو الدولتين لم يعترفوا بالعريضة التي قا...
# 2  أعلن غورو الانتداب الفرنسي على سوريا لكي يعاقب...
# 3  مصر هي أم البلاد، وقائدة العرب؛ فهي أرض بلاد ا...
# 4  الشعب السوري يصر على استقلال بلدهم من السيطرة ...
#
#                                          summary_gen
# 0  وتحت عنوان من الكارثة إلى التحدى يبدأ الكاتب ع...
# 1  ولم يعترف دبلوماسيو هاتين الدولتين بالعريضة ال...
# 2  قامت ولاية حلب بعد اعلان الجنرال الفرنسي هنري ...
# 3  دولة مصر العربيه هي ليست اي دوله وليست اي شعب ...
# 4  السوريون يصرون على استقلال بلادهم : و مثلما رف...

# %%
df.apply(calculate_rouge, axis=1).describe()
# Out:
# count    154.000000
# mean       0.539998
# std        0.150191
# min        0.181818
# 25%        0.436111
# 50%        0.548841
# 75%        0.644512
# max        0.897059
# dtype: float64

# %% [markdown]
# # test

# %%
test_df = pd.read_json('../validation_dataset/test_dataset.jsonl', lines=True)
test_df.head()
# Out:
#    example_id                                          paragraph
# 0           0  وبعد أن ألقينا الضوء على أهم فتوحات بلاد الشام...
# 1           1  الفتوحات الإسلامية في عصر الخلفاء الراشدين .\n...
# 2           2  فتوحات بلاد شمال إفريقيا .\nقام المسلمون بالتو...
# 3           3  وبعد أن ألقينا الضوء على أهم فتوحات بلاد شمال ...
# 4           4  عزيزي الطالب / عزيزتي الطالبة ...\nبعد أن توقف...

# %%
test_df["summary"] = test_df["paragraph"].apply(summarize_arabic_text)
test_df.head()
# Out:
#    example_id                                          paragraph  \
# 0           0  وبعد أن ألقينا الضوء على أهم فتوحات بلاد الشام...
# 1           1  الفتوحات الإسلامية في عصر الخلفاء الراشدين .\n...
# 2           2  فتوحات بلاد شمال إفريقيا .\nقام المسلمون بالتو...
# 3           3  وبعد أن ألقينا الضوء على أهم فتوحات بلاد شمال ...
# 4           4  عزيزي الطالب / عزيزتي الطالبة ...\nبعد أن توقف...
#
#                                              summary
# 0  وبعد أن ألقينا الضوء على أهم فتوحات بلاد الشام...
# 1  وبعد أن انتهى عمر بن الخطابة من خطبته، دعاه ال...
# 2  فتوحات بلاد شمال إفريقيا . قام المسلمون بالتوج...
# 3  وبعد أن ألقينا الضوء على أهم فتوحات بلاد شمال ...
# 4  عزيزي الطالب / عزيزتي الطالبة ...\nبعد أن توقف...

# %%
test_df.loc[0, "summary"]
# Out:
# 'وبعد أن ألقينا الضوء على أهم فتوحات بلاد الشام تعال معا نتناول بيت المقدس بوصفه نموذجا لفتوحات هذه البلاد بشيء من التفصيل . فتح بيت المقدس ١٥هـ / ٦٣٦م:\nلحق عمرو بن العاص بالروم، وشدد عليهم الحصار ، ولم يتمكن الروم من فكه، وهرب الأرطبون إلى مصر مركز ثقل الوجود البيزنطي في إفريقيا لصد هجمات المسلمين. وأثناء الحصار كانت تجرى محادثات لدخول أهل بيت المقدس في الصلح مع المسلمين، فلم يجد بطريرك بيت المقدس أمامه سوى المصالحة، ولكنه اشترط أن يتم الصلح مع الخليفة عمر بن الخطاب بنفسه وذلك لما للمدينة من قدسية وأهمية دينية كبيرة، فأرسل عمرو بن العاص بهذه الأخبار إلى الخليفة بالمدينة النبوية، وقال له في رسالته: "إني أعالج حربا كؤدًا صدومًا وبلادا ادخرت لك فلك رأيك" فكان أول خروج للخليفة من المدينة بعد موت رسول الله ، هذا الخروج الأجل لكي يفتح بيت المقدس . وكان أول نزول له بمدن الشام بالجابية، والتي وفدت عليه فيها رسل البطريرك طالبين الصلح، فصالحهم عمر صلحا لم تحظ به مدينة أخرى في البلاد المفتوحة.... \nهل تعرف شروط هذا الصلح ؟\nاقرأ النص التالى لتتعرف كيف كان الخليفة عمر سخيا في منحه الامتيازات لأهل إيلياء (بيت المقدس). عهد الأمان\n"بسم الله الرحمن الرحيم: هذا ما أعطى عبد الله عمر أمير المؤمنين أهل إيلياء من الأمان، أعطاهم أمانا لأنفسهم وأموالهم وكنائسهم، وصلبانهم، وسقيمها وبريئها، وسائر ملتها، أنه لا تسكن كنائسهم، ولا تهدم، ولا ينتقص منها ولا من حيزها ولا من صليبهم، وشيء من أموالهم، ولا يكرهون على دينهم، ولا يضار أحد منهم، ولا يسكن بإيلياء أحد من اليهود، وعلى أهل إيلياء الجزية كما يعطي أهل المدائن وعليهم أن يخرجوا منها الروم، واللصوص، فمن خرج منهم، فإنه أمن على نفسه وماله حتى يبلغوا مأمنهم، ومن أقام منهم فهو آمن وعليه مثل ما على أهل إيلياء من الجزية ومن أحب من أهل إيلياء أن يسير بنفسه وماله مع الروم ويخلي بيعهم وصلبهم فإنهم آمنون على أنفسهم وعلى بيعهم وصلبهم حتى يبلغوا مأمنهم، ومن شاء رجع إلى أهله فإنه لا يؤخذ منهم شيء حتى يحصد حصادهم، وعلى ما في هذا الكتاب عهد الله وذمة رسوله وذمة الخلفاء وذمة المؤمنين إذا أعطوا الذي عليهم من الجزية.'

# %%
selected_columns = ['example_id', 'summary']
df_selected = test_df[selected_columns]
df_selected.head()
# Out:
#    example_id                                            summary
# 0           0  وبعد أن ألقينا الضوء على أهم فتوحات بلاد الشام...
# 1           1  وبعد أن انتهى عمر بن الخطابة من خطبته، دعاه ال...
# 2           2  فتوحات بلاد شمال إفريقيا . قام المسلمون بالتوج...
# 3           3  وبعد أن ألقينا الضوء على أهم فتوحات بلاد شمال ...
# 4           4  عزيزي الطالب / عزيزتي الطالبة ...\nبعد أن توقف...

# %%
df_selected.to_json("predictions.jsonl", lines=True, orient='records', force_ascii=False)

# %%
import re
import string
from gensim.models import Word2Vec
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from nltk.corpus import stopwords
import numpy as np
from scipy.spatial.distance import cosine
import pyarabic.araby as araby
import nltk
nltk.download('punkt')


# Calculates cosine similarity
def similarity(v1, v2):
    score = 0.0
    if np.count_nonzero(v1) != 0 and np.count_nonzero(v2) != 0:
        score = ((1 - cosine(v1, v2)) + 1) / 2
    return score

def sent_tokenize(text):
    sents = nltk.sent_tokenize(text)
    sents_filtered = []
    for s in sents:
        sents_filtered.append(s)
    return sents_filtered

def cleanup_sentences(text):
    text = re.sub(r'\n', ' ', text)
    stop_words = set(stopwords.words('arabic'))
    sentences = sent_tokenize(text)
    sentences_cleaned = []
    for sent in sentences:
        words = word_tokenize(sent)
        words = [w for w in words if w not in string.punctuation]
        words = [w for w in words if not w.lower() in stop_words]
        words = [araby.strip_tashkeel(w) for w in words]
        sentences_cleaned.append(" ".join(words))
    return sentences_cleaned

def get_tf_idf(sentences):
    vectorizer = CountVectorizer()
    sent_word_matrix = vectorizer.fit_transform(sentences)

    transformer = TfidfTransformer(norm=None, sublinear_tf=False, smooth_idf=False)
    tfidf = transformer.fit_transform(sent_word_matrix)
    tfidf = tfidf.toarray()

    centroid_vector = tfidf.sum(0)
    centroid_vector = np.divide(centroid_vector, centroid_vector.max())

    feature_names = vectorizer.get_feature_names_out()

    relevant_vector_indices = np.where(centroid_vector > 0.3)[0]

    word_list = list(np.array(feature_names)[relevant_vector_indices])
    return word_list

def word_vectors_cache(sentences, embedding_model):
    word_vectors = dict()
    for sent in sentences:
        words = word_tokenize(sent)
        for w in words:
            word_vectors.update({w: embedding_model.wv[w]})
    return word_vectors

def build_embedding_representation(words, word_vectors, embedding_model):
    embedding_representation = np.zeros(embedding_model.vector_size, dtype="float32")
    word_vectors_keys = set(word_vectors.keys())
    count = 0
    for w in words:
        if w in word_vectors_keys:
            embedding_representation = embedding_representation + word_vectors[w]
            count += 1
    if count != 0:
        embedding_representation = np.divide(embedding_representation, count)
    return embedding_representation

def summarize(text, embedding_model):
    raw_sentences = sent_tokenize(text)
    clean_sentences = cleanup_sentences(text)
#     for i, s in enumerate(raw_sentences):
#         print(i, s)
#     for i, s in enumerate(clean_sentences):
#         print(i, s)
    centroid_words = get_tf_idf(clean_sentences)
#     print(len(centroid_words), centroid_words)
    word_vectors = word_vectors_cache(clean_sentences, embedding_model)
    centroid_vector = build_embedding_representation(centroid_words, word_vectors, embedding_model)
    sentences_scores = []
    for i in range(len(clean_sentences)):
        scores = []
        words = clean_sentences[i].split()

        sentence_vector = build_embedding_representation(words, word_vectors, embedding_model)

        score = similarity(sentence_vector, centroid_vector)
        sentences_scores.append((i, raw_sentences[i], score, sentence_vector))
    sentence_scores_sort = sorted(sentences_scores, key=lambda el: el[2], reverse=True)
#     for s in sentence_scores_sort:
#         print(s[0], s[1], s[2])
    count = 0
    sentences_summary = []
    for s in sentence_scores_sort:
        if count > 50:
            break
        include_flag = True
        for ps in sentences_summary:
            sim = similarity(s[3], ps[3])
            if sim > 0.95:
                include_flag = False
        if include_flag:
            sentences_summary.append(s)
            count += len(s[1].split())

        sentences_summary = sorted(sentences_summary, key=lambda el: el[0], reverse=False)

    summary = "\n".join([s[1] for s in sentences_summary])
    return summary

text = """في محاولة لبناء قوى عمل جاهزة للذكاء الاصطناعي، أعلنت مايكروسوفت عن "مركز Intelligent Cloud Hub"
الذي تم إطلاقه لتمكين الجيل القادم من الطلاب بالمهارات الجاهزة للذكاء الاصطناعي.
وصفت بأنها برنامج تعاوني لمدة ثلاث سنوات، سيدعم Intelligent Cloud Hub حوالي 100 مؤسسة ببنية تحتية للذكاء الاصطناعي،
ومحتوى الدورة والمنهاج والدعم للمطورين، وأدوات التطوير ويوفر للطلاب الوصول إلى الخدمات السحابية والذكاء الاصطناعي.
كجزء من البرنامج، ستقوم الشركة بتوفير أدوات تطوير الذكاء الاصطناعي وخدمات Azure AI مثل خدمات Microsoft Cognitive وخدمات Bot وAzure Machine Learning.
وفقًا لـ Manish Prakash، المدير العام للبلاد - PS والصحة والتعليم، مايكروسوفت الهند، قال: "مع الذكاء الاصطناعي الذي يعد التكنولوجيا المحددة لعصرنا،
فإنه يحول الحياة والصناعة والوظائف في المستقبل ستتطلب مهارات مختلفة. هذا يتطلب المزيد من التعاون والتدريب والعمل مع الذكاء الاصطناعي.
لهذا السبب أصبح أكثر أهمية من أي وقت مضى أن تدمج المؤسسات التعليمية التكنولوجيا السحابية والذكاء الاصطناعي الجديدة.
إن البرنامج هو محاولة لزيادة الترتيب المؤسسي وبناء القدرات بين المعلمين لتعليم قوى العمل في المستقبل."
يهدف البرنامج إلى بناء المهارات المعرفية والفهم العميق لتطوير حلول ذكية متصلة بالسحابة للتطبيقات في جميع الصناعات.
في وقت سابق من شهر أبريل من هذا العام، أعلنت الشركة عن برنامج Microsoft Professional
Program في الذكاء الاصطناعي كمسار تعلم متاح للجمهور.
تم تطوير البرنامج لتزويد المبرمجين بالمهارات الجاهزة للعمل في مجال الذكاء الاصطناعي وعلوم البيانات من خلال سلسلة من الدورات عبر الإنترنت التي تضم مختبرات عملية ومحاضرين متخصصين.
شمل البرنامج أيضًا مدرسة تركز على المطورين للذكاء الاصطناعي وتوفر مجموعة من الأصول لمساعدة في بناء مهارات الذكاء الاصطناعي."""
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mohee\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def summarizer(text):
    clean_sentences = cleanup_sentences(text)
    words = []
    for sent in clean_sentences:
        words.append(word_tokenize(sent))
    model = Word2Vec(words, min_count=1, sg=1)
    return summarize(text, model)

text = """وتحت عنوان من الكارثة إلى التحدى يبدأ الكاتب عرض الكتاب الرابع ، حيث يوضح كيف كانت إسرائيل فرحة بنصرها عام 67 وأنها ارتاحت لاعتقادها بأن هناك وقتا طويلا وطويلا جدا قبل أن يفيق العرب من صدمة 67، وكيف أن القوات الجوية للجمهورية العربية المتحدة قد فاجأتها بعد شهر واحد من نهاية حرب 67 بهجوم جوى عنيف على مواقعها فى سيناء وكان هذا إعلانا عن بداية حرب من نوع جديد هى حرب الاستنزاف التى استمرت حتى تم وقف إطلاق النار بين الطرفين فى 8 أغسطس 1970، ثم وفاة عبدالناصر وتولى أنور السادات حكم مصر واستعداده للحرب . ويتعرض الكاتب أيضا وبصورة سريعة لفلسطين والأردن وسوريا قبل أن ينتقل إلى الكتاب الخامس عن حرب أكتوبر ، حيث يعرض الخطط والاستعدادات المصرية ثم الاستعدادات الإسرائيلية ثم يبدأ بعرض وقائع الحرب بداية من الضربة الجوية وانهيار خط بارليف واختراقه ، ويتوقف الكاتب عند يوم 8 أكتوبر ، ويقول : إن هذا اليوم كان اسوأ هزيمة فى تاريخ الجيش الإسرائيلى ثم ينتقل بنا المؤلف إلى الجبهة السورية ثم يعود ثانية إلى يوميات الحرب حتى 7 9 أكتوبر إلى 9 13 أكتوبر ثم 14 أكتوبر ، ثم يعرض للثغرة أو ما عرف بعملية المزرعة الصينية يوم 16 و 15 أكتوبر والمساعدات الأمريكية الضخمة لإسرائيل ، ثم بداية الضغوط السياسية على الرئيس أنور السادات من 17 19 أكتوبر ثم ينتقل الكاتب للأحداث التى جرت من 17 20 أكتوبر وإعفاء الفريق الشاذلى من منصبه كرئيس لأركان القوات المسلحة المصرية ، وتولى الفريق الجمسى بدلا منه ثم الاتجاه إلى الموافقة على طلب وقف إطلاق النار والخلاف مع سوريا بشأن هذا الأمر ، ثم بداية الهجوم الإسرائيلى من 19 إلى 22 أكتوبر على الضفة الغربية لقناة السويس والعمليات النهائية فى سوريا 14 23 أكتوبر ، وكيف أن الملك حسين قرر دخول الحرب ضد إسرائيل يوم 9 أكتوبر ، ثم يعرض الكاتب المعركة الخاصة بالاستيلاء على مدينة السويس من 23 أكتوبر إلى 25 أكتوبر ثم تطورات هذه المعركة ، وكيف أنه مع حلول يوم السابع والعشرين من أكتوبر كان الإسرائيليون قد أسروا نحو ثمانية آلاف فرد من القوات المصرية ، أغلبهم من وحدات الإمداد والتموين ."""

print(summarizer(text))
# Out:
# ويتعرض الكاتب أيضا وبصورة سريعة لفلسطين والأردن وسوريا قبل أن ينتقل إلى الكتاب الخامس عن حرب أكتوبر ، حيث يعرض الخطط والاستعدادات المصرية ثم الاستعدادات الإسرائيلية ثم يبدأ بعرض وقائع الحرب بداية من الضربة الجوية وانهيار خط بارليف واختراقه ، ويتوقف الكاتب عند يوم 8 أكتوبر ، ويقول : إن هذا اليوم كان اسوأ هزيمة فى تاريخ الجيش الإسرائيلى ثم ينتقل بنا المؤلف إلى الجبهة السورية ثم يعود ثانية إلى يوميات الحرب حتى 7 9 أكتوبر إلى 9 13 أكتوبر ثم 14 أكتوبر ، ثم يعرض للثغرة أو ما عرف بعملية المزرعة الصينية يوم 16 و 15 أكتوبر والمساعدات الأمريكية الضخمة لإسرائيل ، ثم بداية الضغوط السياسية على الرئيس أنور السادات من 17 19 أكتوبر ثم ينتقل الكاتب للأحداث التى جرت من 17 20 أكتوبر وإعفاء الفريق الشاذلى من منصبه كرئيس لأركان القوات المسلحة المصرية ، وتولى الفريق الجمسى بدلا منه ثم الاتجاه إلى الموافقة على طلب وقف إطلاق النار والخلاف مع سوريا بشأن هذا الأمر ، ثم بداية الهجوم الإسرائيلى من 19 إلى 22 أكتوبر على الضفة الغربية لقناة السويس والعمليات النهائية فى سوريا 14 23 أكتوبر ، وكيف أن الملك حسين قرر دخول الحرب ضد إسرائيل يوم 9 أكتوبر ، ثم يعرض الكاتب المعركة الخاصة بالاستيلاء على مدينة السويس من 23 أكتوبر إلى 25 أكتوبر ثم تطورات هذه المعركة ، وكيف أنه مع حلول يوم السابع والعشرين من أكتوبر كان الإسرائيليون قد أسروا نحو ثمانية آلاف فرد من القوات المصرية ، أغلبهم من وحدات الإمداد والتموين .

# %%
python -m spacy download xx_ent_wiki_sm
# Out:
#   Cell In[268], line 1
#     python -m spacy download xx_ent_wiki_sm
#               ^
# SyntaxError: invalid syntax

# %%
original_text = 'وتحت عنوان من الكارثة إلى التحدى يبدأ الكاتب عرض الكتاب الرابع ، حيث يوضح كيف كانت إسرائيل فرحة بنصرها عام 67 وأنها ارتاحت لاعتقادها بأن هناك وقتا طويلا وطويلا جدا قبل أن يفيق العرب من صدمة 67، وكيف أن القوات الجوية للجمهورية العربية المتحدة قد فاجأتها بعد شهر واحد من نهاية حرب 67 بهجوم جوى عنيف على مواقعها فى سيناء وكان هذا إعلانا عن بداية حرب من نوع جديد هى حرب الاستنزاف التى استمرت حتى تم وقف إطلاق النار بين الطرفين فى 8 أغسطس 1970، ثم وفاة عبدالناصر وتولى أنور السادات حكم مصر واستعداده للحرب . ويتعرض الكاتب أيضا وبصورة سريعة لفلسطين والأردن وسوريا قبل أن ينتقل إلى الكتاب الخامس عن حرب أكتوبر ، حيث يعرض الخطط والاستعدادات المصرية ثم الاستعدادات الإسرائيلية ثم يبدأ بعرض وقائع الحرب بداية من الضربة الجوية وانهيار خط بارليف واختراقه ، ويتوقف الكاتب عند يوم 8 أكتوبر ، ويقول : إن هذا اليوم كان اسوأ هزيمة فى تاريخ الجيش الإسرائيلى ثم ينتقل بنا المؤلف إلى الجبهة السورية ثم يعود ثانية إلى يوميات الحرب حتى 7 9 أكتوبر إلى 9 13 أكتوبر ثم 14 أكتوبر ، ثم يعرض للثغرة أو ما عرف بعملية المزرعة الصينية يوم 16 و 15 أكتوبر والمساعدات الأمريكية الضخمة لإسرائيل ، ثم بداية الضغوط السياسية على الرئيس أنور السادات من 17 19 أكتوبر ثم ينتقل الكاتب للأحداث التى جرت من 17 20 أكتوبر وإعفاء الفريق الشاذلى من منصبه كرئيس لأركان القوات المسلحة المصرية ، وتولى الفريق الجمسى بدلا منه ثم الاتجاه إلى الموافقة على طلب وقف إطلاق النار والخلاف مع سوريا بشأن هذا الأمر ، ثم بداية الهجوم الإسرائيلى من 19 إلى 22 أكتوبر على الضفة الغربية لقناة السويس والعمليات النهائية فى سوريا 14 23 أكتوبر ، وكيف أن الملك حسين قرر دخول الحرب ضد إسرائيل يوم 9 أكتوبر ، ثم يعرض الكاتب المعركة الخاصة بالاستيلاء على مدينة السويس من 23 أكتوبر إلى 25 أكتوبر ثم تطورات هذه المعركة ، وكيف أنه مع حلول يوم السابع والعشرين من أكتوبر كان الإسرائيليون قد أسروا نحو ثمانية آلاف فرد من القوات المصرية ، أغلبهم من وحدات الإمداد والتموين .'

# %%
from sumy.summarizers.kl import KLSummarizer

# %%
# Creating the parser
from sumy.nlp.tokenizers import Tokenizer
from sumy.parsers.plaintext import PlaintextParser
parser=PlaintextParser.from_string(original_text,Tokenizer('arabic'))

# %%
# Import the summarizer
from sumy.summarizers.lsa import LsaSummarizer

# %%
# Parsing the text string using PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.parsers.plaintext import PlaintextParser
parser=PlaintextParser.from_string(original_text,Tokenizer('arabic'))

# %%
# creating the summarizer
lsa_summarizer=LsaSummarizer()
lsa_summary= lsa_summarizer(parser.document,3)

lsa_summary
# Out:
# (<Sentence: حيث يوضح كيف كانت إسرائيل فرحة بنصرها عام 67 وأنها ارتاحت لاعتقادها بأن هناك وقتا طويلا وطويلا جدا قبل أن يفيق العرب من صدمة 67،>,
#  <Sentence: ويتعرض الكاتب أيضا وبصورة سريعة لفلسطين والأردن وسوريا قبل أن ينتقل إلى الكتاب الخامس عن حرب أكتوبر ،>,
#  <Sentence: وتولى الفريق الجمسى بدلا منه ثم الاتجاه إلى الموافقة على طلب وقف إطلاق النار والخلاف مع سوريا بشأن هذا الأمر ،>)

# %%
import re
from nltk.tokenize import word_tokenize
from pyarabic.araby import tokenize
from nltk.corpus import stopwords
import heapq
import nltk

# %%
def summarizer(article_text):
    article_text = re.sub(r'\n', ' ', article_text)
    article_text = re.sub(r'\s+', ' ', article_text)
    article_text = re.sub(r',', '', article_text)

    formatted_article_text = re.sub('[^\u0621-\u064A\u0660-\u0669 ]', ' ', article_text)
    formatted_article_text = re.sub(r'\s+', ' ', formatted_article_text)
    # Set the appropriate language code for Arabic stopwords
    stopwords = nltk.corpus.stopwords.words('arabic')

    word_frequencies = {}
    for word in nltk.word_tokenize(formatted_article_text):
        if word not in stopwords:
            if word not in word_frequencies.keys():
                word_frequencies[word] = 1
            else:
                word_frequencies[word] += 1
    sentence_list = nltk.sent_tokenize(article_text)
    # Step 4: Calculate word frequencies
    word_frequencies = {}
    for word in tokenize(formatted_article_text):
        if word not in stopwords:
            if word not in word_frequencies.keys():
                word_frequencies[word] = 1
            else:
                word_frequencies[word] += 1

    # Step 5: Calculate sentence scores
    maximum_frequency = max(word_frequencies.values())
    for word in word_frequencies.keys():
        word_frequencies[word] = (word_frequencies[word] / maximum_frequency)
    sentence_scores = {}
    for sent in sentence_list:
        for word in tokenize(sent):
            if word in word_frequencies.keys():
                if len(sent.split('2')) < 30:
                    if sent not in sentence_scores.keys():
                        sentence_scores[sent] = word_frequencies[word]
                    else:
                        sentence_scores[sent] += word_frequencies[word]

    # Step 6: Get the top sentences based on scores
    summary_sentences = heapq.nlargest(3, sentence_scores, key=sentence_scores.get)
    summary = ' '.join(summary_sentences)
    return summary

# %%
import re
import heapq
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem import ISRIStemmer
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

import re
import heapq
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem import ISRIStemmer
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def preprocess_arabic_text(text):
    # Convert to lowercase
    text = text.lower()

    # Remove non-Arabic characters, symbols, and unicode characters
    text = re.sub('[^ء-ي0-9a-z ]', ' ', text)

    # Remove diacritics (Tashkeel)
    text = remove_diacritics(text)

    # Remove Arabic numerals
    text = remove_arabic_numerals(text)
    
    text = delete_links(text)
    text = delete_repeated_characters(text)

    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)

    # Normalize whitespace and remove duplicates
    text = re.sub(r'\s+', ' ', text)

    return text

def remove_diacritics(text):
    diacritics = re.compile(r'[\u0617-\u061A\u064B-\u0652]')
    return re.sub(diacritics, '', text)

def remove_arabic_numerals(text):
    arabic_numerals = {
        '٠': 'صفر',
        '١': 'واحد',
        '٢': 'اثنان',
        '٣': 'ثلاثة',
        '٤': 'أربعة',
        '٥': 'خمسة',
        '٦': 'ستة',
        '٧': 'سبعة',
        '٨': 'ثمانية',
        '٩': 'تسعة'
    }
    for numeral, word_form in arabic_numerals.items():
        text = text.replace(numeral, word_form)
    return text

def delete_links(input_text):
    pettern  = r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))'''
    out_text = re.sub(pettern, ' ', input_text)
    return out_text

def delete_repeated_characters(input_text):
    pattern  = r'(.)\1{2,}'
    out_text = re.sub(pattern, r"\1\1", input_text)
    return out_text


def summarize_text(text, num_sentences=1):
    text = preprocess_arabic_text(text)

    # Sentence Tokenization
    sentence_list = nltk.sent_tokenize(text)

    sentence_list = nltk.sent_tokenize(text)
    SentenceList = []
    #sentence_list
    for i in range(len(sentence_list)):
        # Split the paragraph by "،"
        sentences = sentence_list[i].split(".")

        # Print the sentences
        for sentence in sentences:
            #  print(sentence.strip())
            SentenceList.append(sentence)
    stopwords = nltk.corpus.stopwords.words('arabic')


    word_frequencies = {}
    for word in nltk.word_tokenize(text):
        if word not in stopwords:
            if word not in word_frequencies.keys():
                word_frequencies[word] = 1
            else:
                word_frequencies[word] += 1
    # print(word_frequencies.items())

    maximum_frequncy = max(word_frequencies.values())

    for word in word_frequencies.keys():
        word_frequencies[word] = (word_frequencies[word]/maximum_frequncy)
    # print(word_frequencies)

    sentence_scores = {}
    for sent in SentenceList:
        for word in nltk.word_tokenize(sent):
            if word in word_frequencies.keys():
                if len(sent.split('.')) < 30:
                    if sent not in sentence_scores.keys():
                        sentence_scores[sent] = word_frequencies[word]
                    else:
                        sentence_scores[sent] += word_frequencies[word]
    # print(sentence_scores)

    # Step 8: Get the top sentences based on scores
    summary_sentences = heapq.nlargest(4, sentence_scores, key=sentence_scores.get)

    summary = ' '.join(summary_sentences)
    return summary



def additional_stopwords():
    stopwords = """فى
في
كل
لم
لن
له
من
هو
هي
قوة
كما
لها
منذ
وقد
ولا
نفسه
لقاء
مقابل
هناك
وقال
وكان
نهاية
وقالت
وكانت
للامم
فيه
كلم
لكن

وفي
وقف
ولم
ومن
وهو
وهي
يوم
فيها
منها
مليار
لوكالة
يكون
يمكن
مليون
حيث
اكد
الا
اما
امس
السابق
التى
التي
اكثر
ايار
ايضا
ثلاثة
الذاتي
الاخيرة
الثاني
الثانية
الذى
الذي

الان
امام
ايام
خلال
حوالى
الذين
الاول
الاولى
بين
ذلك
دون
حول
حين
الف
الى
انه
اول
ضمن
انها
جميع
الماضي
الوقت
المقبل
اليوم
ـ
ف
و
و6
قد
لا
ما
مع

مساء
هذا
واحد
واضاف
واضافت
فان
قبل
قال
كان
لدى
نحو
هذه
وان
واكد
كانت
واوضح
مايو
ب
ا
أ
،
عشر
عدد
عدة
عشرة
عدم
عام
عاما
عن
عند
عندما
على

عليه
عليها
زيارة
سنة
سنوات
تم
ضد
بعد
بعض
اعادة
اعلنت
بسبب
حتى
اذا
احد
اثر
برس
باسم
غدا
شخصا
صباح
اطار
اربعة
اخرى
بان
اجل
غير
بشكل
حاليا
بن
به
ثم
اف
ان
او
اي
بها
صفر
""".split('\n')

    return stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mohee\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mohee\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\mohee\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mohee\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mohee\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\mohee\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
text = """وتحت عنوان من الكارثة إلى التحدى يبدأ الكاتب عرض الكتاب الرابع ، حيث يوضح كيف كانت إسرائيل فرحة بنصرها عام 67 وأنها ارتاحت لاعتقادها بأن هناك وقتا طويلا وطويلا جدا قبل أن يفيق العرب من صدمة 67، وكيف أن القوات الجوية للجمهورية العربية المتحدة قد فاجأتها بعد شهر واحد من نهاية حرب 67 بهجوم جوى عنيف على مواقعها فى سيناء وكان هذا إعلانا عن بداية حرب من نوع جديد هى حرب الاستنزاف التى استمرت حتى تم وقف إطلاق النار بين الطرفين فى 8 أغسطس 1970، ثم وفاة عبدالناصر وتولى أنور السادات حكم مصر واستعداده للحرب . ويتعرض الكاتب أيضا وبصورة سريعة لفلسطين والأردن وسوريا قبل أن ينتقل إلى الكتاب الخامس عن حرب أكتوبر ، حيث يعرض الخطط والاستعدادات المصرية ثم الاستعدادات الإسرائيلية ثم يبدأ بعرض وقائع الحرب بداية من الضربة الجوية وانهيار خط بارليف واختراقه ، ويتوقف الكاتب عند يوم 8 أكتوبر ، ويقول : إن هذا اليوم كان اسوأ هزيمة فى تاريخ الجيش الإسرائيلى ثم ينتقل بنا المؤلف إلى الجبهة السورية ثم يعود ثانية إلى يوميات الحرب حتى 7 9 أكتوبر إلى 9 13 أكتوبر ثم 14 أكتوبر ، ثم يعرض للثغرة أو ما عرف بعملية المزرعة الصينية يوم 16 و 15 أكتوبر والمساعدات الأمريكية الضخمة لإسرائيل ، ثم بداية الضغوط السياسية على الرئيس أنور السادات من 17 19 أكتوبر ثم ينتقل الكاتب للأحداث التى جرت من 17 20 أكتوبر وإعفاء الفريق الشاذلى من منصبه كرئيس لأركان القوات المسلحة المصرية ، وتولى الفريق الجمسى بدلا منه ثم الاتجاه إلى الموافقة على طلب وقف إطلاق النار والخلاف مع سوريا بشأن هذا الأمر ، ثم بداية الهجوم الإسرائيلى من 19 إلى 22 أكتوبر على الضفة الغربية لقناة السويس والعمليات النهائية فى سوريا 14 23 أكتوبر ، وكيف أن الملك حسين قرر دخول الحرب ضد إسرائيل يوم 9 أكتوبر ، ثم يعرض الكاتب المعركة الخاصة بالاستيلاء على مدينة السويس من 23 أكتوبر إلى 25 أكتوبر ثم تطورات هذه المعركة ، وكيف أنه مع حلول يوم السابع والعشرين من أكتوبر كان الإسرائيليون قد أسروا نحو ثمانية آلاف فرد من القوات المصرية ، أغلبهم من وحدات الإمداد والتموين ."""

summarize_text(text, 1)
# Out:
# 'وتحت عنوان من الكارثة إلى التحدى يبدأ الكاتب عرض الكتاب الرابع حيث يوضح كيف كانت إسرائيل فرحة بنصرها عام 67 وأنها ارتاحت لاعتقادها بأن هناك وقتا طويلا وطويلا جدا قبل أن يفيق العرب من صدمة 67 وكيف أن القوات الجوية للجمهورية العربية المتحدة قد فاجأتها بعد شهر واحد من نهاية حرب 67 بهجوم جوى عنيف على مواقعها فى سيناء وكان هذا إعلانا عن بداية حرب من نوع جديد هى حرب الاستنزاف التى استمرت حتى تم وقف إطلاق النار بين الطرفين فى 8 أغسطس 1970 ثم وفاة عبدالناصر وتولى أنور السادات حكم مصر واستعداده للحرب ويتعرض الكاتب أيضا وبصورة سريعة لفلسطين والأردن وسوريا قبل أن ينتقل إلى الكتاب الخامس عن حرب أكتوبر حيث يعرض الخطط والاستعدادات المصرية ثم الاستعدادات الإسرائيلية ثم يبدأ بعرض وقائع الحرب بداية من الضربة الجوية وانهيار خط بارليف واختراقه ويتوقف الكاتب عند يوم 8 أكتوبر ويقول إن هذا اليوم كان اسوأ هزيمة فى تاريخ الجيش الإسرائيلى ثم ينتقل بنا المؤلف إلى الجبهة السورية ثم يعود ثانية إلى يوميات الحرب حتى 7 9 أكتوبر إلى 9 13 أكتوبر ثم 14 أكتوبر ثم يعرض للثغرة أو ما عرف بعملية المزرعة الصينية يوم 16 و 15 أكتوبر والمساعدات الأمريكية الضخمة لإسرائيل ثم بداية الضغوط السياسية على الرئيس أنور السادات من 17 19 أكتوبر ثم ينتقل الكاتب للأحداث التى جرت من 17 20 أكتوبر وإعفاء الفريق الشاذلى من منصبه كرئيس لأركان القوات المسلحة المصرية وتولى الفريق الجمسى بدلا منه ثم الاتجاه إلى الموافقة على طلب وقف إطلاق النار والخلاف مع سوريا بشأن هذا الأمر ثم بداية الهجوم الإسرائيلى من 19 إلى 22 أكتوبر على الضفة الغربية لقناة السويس والعمليات النهائية فى سوريا 14 23 أكتوبر وكيف أن الملك حسين قرر دخول الحرب ضد إسرائيل يوم 9 أكتوبر ثم يعرض الكاتب المعركة الخاصة بالاستيلاء على مدينة السويس من 23 أكتوبر إلى 25 أكتوبر ثم تطورات هذه المعركة وكيف أنه مع حلول يوم السابع والعشرين من أكتوبر كان الإسرائيليون قد أسروا نحو ثمانية آلاف فرد من القوات المصرية أغلبهم من وحدات الإمداد والتموين'

# %%
text
# Out:
# 'وتحت عنوان من الكارثة إلى التحدى يبدأ الكاتب عرض الكتاب الرابع ، حيث يوضح كيف كانت إسرائيل فرحة بنصرها عام 67 وأنها ارتاحت لاعتقادها بأن هناك وقتا طويلا وطويلا جدا قبل أن يفيق العرب من صدمة 67، وكيف أن القوات الجوية للجمهورية العربية المتحدة قد فاجأتها بعد شهر واحد من نهاية حرب 67 بهجوم جوى عنيف على مواقعها فى سيناء وكان هذا إعلانا عن بداية حرب من نوع جديد هى حرب الاستنزاف التى استمرت حتى تم وقف إطلاق النار بين الطرفين فى 8 أغسطس 1970، ثم وفاة عبدالناصر وتولى أنور السادات حكم مصر واستعداده للحرب . ويتعرض الكاتب أيضا وبصورة سريعة لفلسطين والأردن وسوريا قبل أن ينتقل إلى الكتاب الخامس عن حرب أكتوبر ، حيث يعرض الخطط والاستعدادات المصرية ثم الاستعدادات الإسرائيلية ثم يبدأ بعرض وقائع الحرب بداية من الضربة الجوية وانهيار خط بارليف واختراقه ، ويتوقف الكاتب عند يوم 8 أكتوبر ، ويقول : إن هذا اليوم كان اسوأ هزيمة فى تاريخ الجيش الإسرائيلى ثم ينتقل بنا المؤلف إلى الجبهة السورية ثم يعود ثانية إلى يوميات الحرب حتى 7 9 أكتوبر إلى 9 13 أكتوبر ثم 14 أكتوبر ، ثم يعرض للثغرة أو ما عرف بعملية المزرعة الصينية يوم 16 و 15 أكتوبر والمساعدات الأمريكية الضخمة لإسرائيل ، ثم بداية الضغوط السياسية على الرئيس أنور السادات من 17 19 أكتوبر ثم ينتقل الكاتب للأحداث التى جرت من 17 20 أكتوبر وإعفاء الفريق الشاذلى من منصبه كرئيس لأركان القوات المسلحة المصرية ، وتولى الفريق الجمسى بدلا منه ثم الاتجاه إلى الموافقة على طلب وقف إطلاق النار والخلاف مع سوريا بشأن هذا الأمر ، ثم بداية الهجوم الإسرائيلى من 19 إلى 22 أكتوبر على الضفة الغربية لقناة السويس والعمليات النهائية فى سوريا 14 23 أكتوبر ، وكيف أن الملك حسين قرر دخول الحرب ضد إسرائيل يوم 9 أكتوبر ، ثم يعرض الكاتب المعركة الخاصة بالاستيلاء على مدينة السويس من 23 أكتوبر إلى 25 أكتوبر ثم تطورات هذه المعركة ، وكيف أنه مع حلول يوم السابع والعشرين من أكتوبر كان الإسرائيليون قد أسروا نحو ثمانية آلاف فرد من القوات المصرية ، أغلبهم من وحدات الإمداد والتموين .'

# %%
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize


def preprocess_arabic_text(text):
    # Remove non-Arabic characters and punctuations
    text = re.sub(r'[^\u0600-\u06FF\s]', '', text)

    # Convert text to lowercase
    text = text.lower()

    # Remove diacritics
    text = remove_diacritics(text)

    # Remove stopwords
    stop_words = set(stopwords.words('arabic'))
    words = word_tokenize(text)
    words = [word for word in words if word not in stop_words]

    # Join the words back into a preprocessed text
    preprocessed_text = ' '.join(words)

    return preprocessed_text


def remove_diacritics(text):
    diacritic_letters = {
        'َ': '',  # Fatha
        'ً': '',  # Tanwin Fath
        'ُ': '',  # Damma
        'ٌ': '',  # Tanwin Damm
        'ِ': '',  # Kasra
        'ٍ': '',  # Tanwin Kasr
        'ْ': '',  # Sukun
        'ّ': ''  # Shadda
    }

    for diacritic, replacement in diacritic_letters.items():
        text = text.replace(diacritic, replacement)

    return text


def summarize_arabic_text(text, num_sentences=20):
    # Tokenize the text into sentences
    sentences = sent_tokenize(text)

    # Remove any leading/trailing white spaces in each sentence
    sentences = [sentence.strip() for sentence in sentences]

    # Preprocess each sentence
    preprocessed_sentences = [preprocess_arabic_text(sentence) for sentence in sentences]

    # Join the preprocessed sentences into a single text
    preprocessed_text = ' '.join(preprocessed_sentences)

    # Tokenize the preprocessed text into words
    words = word_tokenize(preprocessed_text)

    # Calculate the frequency of each word
    word_frequencies = {}
    for word in words:
        if word not in word_frequencies:
            word_frequencies[word] = 1
        else:
            word_frequencies[word] += 1

    # Sort the words by frequency in descending order
    sorted_words = sorted(word_frequencies, key=word_frequencies.get, reverse=True)

    # Select the top N sentences based on word frequency
    summary_sentences = []
    for sentence in sentences:
        if len(summary_sentences) < num_sentences:
            if any(word in sentence for word in sorted_words[:5]):
                summary_sentences.append(sentence)
        else:
            break

    # Join the summary sentences into a single summary text
    summary_text = ' '.join(summary_sentences)

    return summary_text

# %%
df["summary_gen"] = df["paragraph"].apply(summarize_arabic_text)
