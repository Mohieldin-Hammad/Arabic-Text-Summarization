# %%
article_text = """تحت عنوان من الكارثة إلى التحدى يبدأ الكاتب عرض الكتاب الرابع ، حيث يوضح كيف كانت إسرائيل فرحة بنصرها عام 67 وأنها ارتاحت لاعتقادها بأن هناك وقتا طويلا وطويلا جدا قبل أن يفيق العرب من صدمة 67، وكيف أن القوات الجوية للجمهورية العربية المتحدة قد فاجأتها بعد شهر واحد من نهاية حرب 67 بهجوم جوى عنيف على مواقعها فى سيناء وكان هذا إعلانا عن بداية حرب من نوع جديد هى حرب الاستنزاف التى استمرت حتى تم وقف إطلاق النار بين الطرفين فى 8 أغسطس 1970، ثم وفاة عبدالناصر وتولى أنور السادات حكم مصر واستعداده للحرب . ويتعرض الكاتب أيضا وبصورة سريعة لفلسطين والأردن وسوريا قبل أن ينتقل إلى الكتاب الخامس عن حرب أكتوبر ، حيث يعرض الخطط والاستعدادات المصرية ثم الاستعدادات الإسرائيلية ثم يبدأ بعرض وقائع الحرب بداية من الضربة الجوية وانهيار خط بارليف واختراقه ، ويتوقف الكاتب عند يوم 8 أكتوبر ، ويقول : إن هذا اليوم كان اسوأ هزيمة فى تاريخ الجيش الإسرائيلى ثم ينتقل بنا المؤلف إلى الجبهة السورية ثم يعود ثانية إلى يوميات الحرب حتى 7 9 أكتوبر إلى 9 13 أكتوبر ثم 14 أكتوبر ، ثم يعرض للثغرة أو ما عرف بعملية المزرعة الصينية يوم 16 و 15 أكتوبر والمساعدات الأمريكية الضخمة لإسرائيل ، ثم بداية الضغوط السياسية على الرئيس أنور السادات من 17 19 أكتوبر ثم ينتقل الكاتب للأحداث التى جرت من 17 20 أكتوبر وإعفاء الفريق الشاذلى من منصبه كرئيس لأركان القوات المسلحة المصرية ، وتولى الفريق الجمسى بدلا منه ثم الاتجاه إلى الموافقة على طلب وقف إطلاق النار والخلاف مع سوريا بشأن هذا الأمر ، ثم بداية الهجوم الإسرائيلى من 19 إلى 22 أكتوبر على الضفة الغربية لقناة السويس والعمليات النهائية فى سوريا 14 23 أكتوبر ، وكيف أن الملك حسين قرر دخول الحرب ضد إسرائيل يوم 9 أكتوبر ، ثم يعرض الكاتب المعركة الخاصة بالاستيلاء على مدينة السويس من 23 أكتوبر إلى 25 أكتوبر ثم تطورات هذه المعركة ، وكيف أنه مع حلول يوم السابع والعشرين من أكتوبر كان الإسرائيليون قد أسروا نحو ثمانية آلاف فرد من القوات المصرية ، أغلبهم من وحدات الإمداد والتموين ."""
# article_text = "وبعد أن ألقينا الضوء على أهم فتوحات بلاد الشام تعال معا نتناول بيت المقدس بوصفه نموذجا لفتوحات هذه البلاد بشيء من التفصيل .\nفتح بيت المقدس ١٥هـ \/ ٦٣٦م:\nلحق عمرو بن العاص بالروم، وشدد عليهم الحصار ، ولم يتمكن الروم من فكه، وهرب الأرطبون إلى مصر مركز ثقل الوجود البيزنطي في إفريقيا لصد هجمات المسلمين.\nوأثناء
# 'تحت عنوان من الكارثة إلى التحدى يبدأ الكاتب عرض الكتاب الرابع ، حيث يوضح كيف كانت إسرائيل فرحة بنصرها عام 67 وأنها ارتاحت لاعتقادها بأن هناك وقتا طويلا وطويلا جدا قبل أن يفيق العرب من صدمة 67، وكيف أن القوات الجوية للجمهورية العربية المتحدة قد فاجأتها بعد شهر واحد من نهاية حرب 67 بهجوم جوى عنيف على مواقعها فى سيناء وكان هذا إعلانا عن بداية حرب من نوع جديد هى حرب الاستنزاف التى استمرت حتى تم وقف إطلاق النار بين الطرفين فى 8 أغسطس 1970، ثم وفاة عبدالناصر وتولى أنور السادات حكم مصر واستعداده للحرب . ويتعرض الكاتب أيضا وبصورة سريعة لفلسطين والأردن وسوريا قبل أن ينتقل إلى الكتاب الخامس عن حرب أكتوبر ، حيث يعرض الخطط والاستعدادات المصرية ثم الاستعدادات الإسرائيلية ثم يبدأ بعرض وقائع الحرب بداية من الضربة الجوية وانهيار خط بارليف واختراقه ، ويتوقف الكاتب عند يوم 8 أكتوبر ، ويقول : إن هذا اليوم كان اسوأ هزيمة فى تاريخ الجيش الإسرائيلى ثم ينتقل بنا المؤلف إلى الجبهة السورية ثم يعود ثانية إلى يوميات الحرب حتى 7 9 أكتوبر إلى 9 13 أكتوبر ثم 14 أكتوبر ، ثم يعرض للثغرة أو ما عرف بعملية المزرعة ال
# ...

# %%
import re
article_text = re.sub(r'\n', ' ', article_text)
article_text = re.sub(r'\s+', ' ', article_text)
article_text = re.sub(r',', '', article_text)

formatted_article_text = re.sub('[^\u0621-\u064A\u0660-\u0669 ]', ' ', article_text)
formatted_article_text = re.sub(r'\s+', ' ', formatted_article_text)
formatted_article_text
# Out:
# 'تحت عنوان من الكارثة إلى التحدى يبدأ الكاتب عرض الكتاب الرابع حيث يوضح كيف كانت إسرائيل فرحة بنصرها عام وأنها ارتاحت لاعتقادها بأن هناك وقتا طويلا وطويلا جدا قبل أن يفيق العرب من صدمة وكيف أن القوات الجوية للجمهورية العربية المتحدة قد فاجأتها بعد شهر واحد من نهاية حرب بهجوم جوى عنيف على مواقعها فى سيناء وكان هذا إعلانا عن بداية حرب من نوع جديد هى حرب الاستنزاف التى استمرت حتى تم وقف إطلاق النار بين الطرفين فى أغسطس ثم وفاة عبدالناصر وتولى أنور السادات حكم مصر واستعداده للحرب ويتعرض الكاتب أيضا وبصورة سريعة لفلسطين والأردن وسوريا قبل أن ينتقل إلى الكتاب الخامس عن حرب أكتوبر حيث يعرض الخطط والاستعدادات المصرية ثم الاستعدادات الإسرائيلية ثم يبدأ بعرض وقائع الحرب بداية من الضربة الجوية وانهيار خط بارليف واختراقه ويتوقف الكاتب عند يوم أكتوبر ويقول إن هذا اليوم كان اسوأ هزيمة فى تاريخ الجيش الإسرائيلى ثم ينتقل بنا المؤلف إلى الجبهة السورية ثم يعود ثانية إلى يوميات الحرب حتى أكتوبر إلى أكتوبر ثم أكتوبر ثم يعرض للثغرة أو ما عرف بعملية المزرعة الصينية يوم و أكتوبر والمساعدات الأمريكية الضخمة
# ...

# %%
from nltk.tokenize import word_tokenize
from pyarabic.araby import tokenize
from nltk.corpus import stopwords
import heapq
import nltk

# %%
# Set the appropriate language code for Arabic stopwords
stopwords = nltk.corpus.stopwords.words('arabic')

word_frequencies = {}
for word in nltk.word_tokenize(formatted_article_text):
    if word not in stopwords:
        if word not in word_frequencies.keys():
            word_frequencies[word] = 1
        else:
            word_frequencies[word] += 1
word_frequencies
# Out:
# {'عنوان': 1,
#  'الكارثة': 1,
#  'التحدى': 1,
#  'يبدأ': 2,
#  'الكاتب': 5,
#  'عرض': 1,
#  'الكتاب': 2,
#  'الرابع': 1,
#  'يوضح': 1,
#  'كانت': 1,
#  'إسرائيل': 2,
#  'فرحة': 1,
#  'بنصرها': 1,
#  'عام': 1,
#  'وأنها': 1,
#  'ارتاحت': 1,
#  'لاعتقادها': 1,
#  'بأن': 1,
#  'وقتا': 1,
#  'طويلا': 1,
#  'وطويلا': 1,
#  'جدا': 1,
#  'يفيق': 1,
#  'العرب': 1,
#  'صدمة': 1,
#  'وكيف': 3,
#  'القوات': 3,
#  'الجوية': 2,
#  'للجمهورية': 1,
#  'العربية': 1,
#  'المتحدة': 1,
#  'فاجأتها': 1,
#  'شهر': 1,
#  'نهاية': 1,
#  'حرب': 4,
#  'بهجوم': 1,
#  'جوى': 1,
#  'عنيف': 1,
#  'مواقعها': 1,
#  'فى': 4,
#  'سيناء': 1,
#  'وكان': 1,
#  'إعلانا': 1,
#  'بداية': 4,
#  'نوع': 1,
#  'جديد': 1,
#  'هى': 1,
#  'الاستنزاف': 1,
#  'التى': 2,
#  'استمرت': 1,
#  'تم': 1,
#  'وقف': 2,
#  'إطلاق': 2,
#  'النار': 2,
#  'الطرفين': 1,
#  'وفاة': 1,
#  'عبدالناصر': 1,
#  'وتولى': 2,
#  'أنور': 2,
#  'السادات': 2,
#  'حكم': 1,
#  'مصر': 1,
#  'واستعداده': 1,
#  'للحرب': 1,
#  'ويتعرض': 1,
#  'وبصورة': 1,
# ...

# %%
sentence_list = nltk.sent_tokenize(article_text)
# sentence_list = tokenize(article_text)
sentence_list
# Out:
# ['تحت عنوان من الكارثة إلى التحدى يبدأ الكاتب عرض الكتاب الرابع ، حيث يوضح كيف كانت إسرائيل فرحة بنصرها عام 67 وأنها ارتاحت لاعتقادها بأن هناك وقتا طويلا وطويلا جدا قبل أن يفيق العرب من صدمة 67، وكيف أن القوات الجوية للجمهورية العربية المتحدة قد فاجأتها بعد شهر واحد من نهاية حرب 67 بهجوم جوى عنيف على مواقعها فى سيناء وكان هذا إعلانا عن بداية حرب من نوع جديد هى حرب الاستنزاف التى استمرت حتى تم وقف إطلاق النار بين الطرفين فى 8 أغسطس 1970، ثم وفاة عبدالناصر وتولى أنور السادات حكم مصر واستعداده للحرب .',
# ...

# %%
# Step 4: Calculate word frequencies
word_frequencies = {}
for word in tokenize(formatted_article_text):
    if word not in stopwords:
        if word not in word_frequencies.keys():
            word_frequencies[word] = 1
        else:
            word_frequencies[word] += 1

# Step 5: Calculate sentence scores
maximum_frequency = max(word_frequencies.values())
for word in word_frequencies.keys():
    word_frequencies[word] = (word_frequencies[word] / maximum_frequency)

word_frequencies
# Out:
# {'عنوان': 0.2,
#  'الكارثة': 0.2,
#  'التحدى': 0.2,
#  'يبدأ': 0.4,
#  'الكاتب': 1.0,
#  'عرض': 0.2,
#  'الكتاب': 0.4,
#  'الرابع': 0.2,
#  'يوضح': 0.2,
#  'كانت': 0.2,
#  'إسرائيل': 0.4,
#  'فرحة': 0.2,
#  'بنصرها': 0.2,
#  'عام': 0.2,
#  'وأنها': 0.2,
#  'ارتاحت': 0.2,
#  'لاعتقادها': 0.2,
#  'بأن': 0.2,
#  'وقتا': 0.2,
#  'طويلا': 0.2,
#  'وطويلا': 0.2,
#  'جدا': 0.2,
#  'يفيق': 0.2,
#  'العرب': 0.2,
#  'صدمة': 0.2,
#  'وكيف': 0.6,
#  'القوات': 0.6,
#  'الجوية': 0.4,
#  'للجمهورية': 0.2,
#  'العربية': 0.2,
#  'المتحدة': 0.2,
#  'فاجأتها': 0.2,
#  'شهر': 0.2,
#  'نهاية': 0.2,
#  'حرب': 0.8,
#  'بهجوم': 0.2,
#  'جوى': 0.2,
#  'عنيف': 0.2,
#  'مواقعها': 0.2,
#  'فى': 0.8,
#  'سيناء': 0.2,
#  'وكان': 0.2,
#  'إعلانا': 0.2,
#  'بداية': 0.8,
#  'نوع': 0.2,
#  'جديد': 0.2,
#  'هى': 0.2,
#  'الاستنزاف': 0.2,
#  'التى': 0.4,
#  'استمرت': 0.2,
#  'تم': 0.2,
#  'وقف': 0.4,
#  'إطلاق': 0.4,
#  'النار': 0.4,
#  'الطرفين': 0.2,
#  'وفاة': 0.2,
#  'عبدالناصر': 0.2,
#  'وتولى': 0.4,
# ...

# %%
sentence_scores = {}
for sent in sentence_list:
    for word in tokenize(sent):
        if word in word_frequencies.keys():
            if len(sent.split('2')) < 30:
                if sent not in sentence_scores.keys():
                    sentence_scores[sent] = word_frequencies[word]
                else:
                    sentence_scores[sent] += word_frequencies[word]

sentence_scores
# Out:
# {'عنوان': 0.2,
#  'الكارثة': 0.2,
#  'التحدى': 0.2,
#  'يبدأ': 0.8,
#  'الكاتب': 5.0,
#  'عرض': 0.2,
#  'الكتاب': 0.8,
#  'الرابع': 0.2,
#  'يوضح': 0.2,
#  'كانت': 0.2,
#  'إسرائيل': 0.8,
#  'فرحة': 0.2,
#  'بنصرها': 0.2,
#  'عام': 0.2,
#  'وأنها': 0.2,
#  'ارتاحت': 0.2,
#  'لاعتقادها': 0.2,
#  'بأن': 0.2,
#  'وقتا': 0.2,
#  'طويلا': 0.2,
#  'وطويلا': 0.2,
#  'جدا': 0.2,
#  'يفيق': 0.2,
#  'العرب': 0.2,
#  'صدمة': 0.2,
#  'وكيف': 1.7999999999999998,
#  'القوات': 1.7999999999999998,
#  'الجوية': 0.8,
#  'للجمهورية': 0.2,
#  'العربية': 0.2,
#  'المتحدة': 0.2,
#  'فاجأتها': 0.2,
#  'شهر': 0.2,
#  'نهاية': 0.2,
#  'حرب': 3.2,
#  'بهجوم': 0.2,
#  'جوى': 0.2,
#  'عنيف': 0.2,
#  'مواقعها': 0.2,
#  'فى': 3.2,
#  'سيناء': 0.2,
#  'وكان': 0.2,
#  'إعلانا': 0.2,
#  'بداية': 3.2,
#  'نوع': 0.2,
#  'جديد': 0.2,
#  'هى': 0.2,
#  'الاستنزاف': 0.2,
#  'التى': 0.8,
#  'استمرت': 0.2,
#  'تم': 0.2,
#  'وقف': 0.8,
#  'إطلاق': 0.8,
#  'النار': 0.8,
#  'الطرفين': 0.2,
#  'وفاة': 0.2,
#  'عبدالناصر': 0.2,
# ...

# %%
# Step 6: Get the top sentences based on scores
summary_sentences = heapq.nlargest(int(round(len(sentence_list) * 0.3)), sentence_scores, key=sentence_scores.get)
summary = ' '.join(summary_sentences)
print(summary)
# Out:
# الكاتب حرب فى بداية يوم وكيف القوات ينتقل يعرض المصرية الحرب يبدأ الكتاب إسرائيل الجوية التى وقف إطلاق النار وتولى أنور السادات الإسرائيلى الفريق سوريا السويس المعركة عنوان الكارثة التحدى عرض الرابع يوضح كانت فرحة بنصرها عام وأنها ارتاحت لاعتقادها بأن وقتا طويلا وطويلا جدا يفيق العرب صدمة للجمهورية العربية المتحدة فاجأتها شهر نهاية بهجوم جوى عنيف مواقعها سيناء وكان إعلانا نوع جديد هى الاستنزاف استمرت تم الطرفين وفاة عبدالناصر حكم مصر واستعداده للحرب ويتعرض وبصورة سريعة لفلسطين والأردن وسوريا الخامس الخطط والاستعدادات الاستعدادات الإسرائيلية بعرض وقائع الضربة وانهيار خط بارليف واختراقه ويتوقف ويقول اليوم اسوأ هزيمة تاريخ الجيش المؤلف الجبهة

# %%
def summarizar(text):
    article_text = re.sub(r'\n', ' ', article_text)
    article_text = re.sub(r'\s+', ' ', article_text)
    article_text = re.sub(r',', '', article_text)

    formatted_article_text = re.sub('[^\u0621-\u064A\u0660-\u0669 ]', ' ', article_text)
    formatted_article_text = re.sub(r'\s+', ' ', formatted_article_text)
    # Set the appropriate language code for Arabic stopwords
    stopwords = nltk.corpus.stopwords.words('arabic')

    word_frequencies = {}
    for word in nltk.word_tokenize(formatted_article_text):
        if word not in stopwords:
            if word not in word_frequencies.keys():
                word_frequencies[word] = 1
            else:
                word_frequencies[word] += 1
    sentence_list = nltk.sent_tokenize(article_text)
    # Step 4: Calculate word frequencies
    word_frequencies = {}
    for word in tokenize(formatted_article_text):
        if word not in stopwords:
            if word not in word_frequencies.keys():
                word_frequencies[word] = 1
            else:
                word_frequencies[word] += 1

    # Step 5: Calculate sentence scores
    maximum_frequency = max(word_frequencies.values())
    for word in word_frequencies.keys():
        word_frequencies[word] = (word_frequencies[word] / maximum_frequency)
    sentence_scores = {}
    for sent in sentence_list:
        for word in tokenize(sent):
            if word in word_frequencies.keys():
                if len(sent.split('2')) < 30:
                    if sent not in sentence_scores.keys():
                        sentence_scores[sent] = word_frequencies[word]
                    else:
                        sentence_scores[sent] += word_frequencies[word]

    # Step 6: Get the top sentences based on scores
    summary_sentences = heapq.nlargest(int(round(len(sentence_list) * 0.3)), sentence_scores, key=sentence_scores.get)
    summary = ' '.join(summary_sentences)
    return summary
